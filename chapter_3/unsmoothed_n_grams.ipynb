# %%
from collections import defaultdict
import pandas as pd

# %% [markdown]
# You can find the data used below on this [link](https://www.kaggle.com/datasets/amiramosa99/arabic-tweets-in-different-dialects-clean-data).

# %%
corpora_1 = pd.read_csv("clean_data.csv", encoding='utf-8').loc[:5000, 'tweets']
corpora_2 = pd.read_csv("clean_data.csv", encoding='utf-8').loc[5000:10000, "tweets"]

# %%
# # s = "Muhammad loves Allah and wants to stay on his stright path May Allah accepts Muhammad good deeds What Allah wants happens"
# s = "و قبر حرب ب مكان قفر و ليس قرب قبر حرب قبر أتيت على قبر حرب ف بكيت حرب و أتيت على قبر جدتي بعدها"

def ngrams_analysis(corp):
    total_unigrams = []
    for s in corp:
        unigrams = s.split()
        total_unigrams += unigrams
    # print(total_unigrams)

    unigram_count = defaultdict(int)
    for w in total_unigrams:
        unigram_count[w]+=1
    # print(dict(sorted(unigram_count.items(), key=lambda item: item[1])))

    unigrams_prob = {w: c/len(total_unigrams) for w,c in unigram_count.items()}
    # print(dict(sorted(unigrams_prob.items(), key=lambda item: item[1], reverse=True)))

    bigram_count = defaultdict(int)
    for i in range(len(total_unigrams)-1):
        w1, w2 = total_unigrams[i], total_unigrams[i+1]
        bigram_count[(w1, w2)] += 1
    # print(dict(sorted(bigram_count.items(), key=lambda item: item[1], reverse=True)))

    bigrams_prob = {bigram: c/unigram_count[bigram[0]] for bigram,c in bigram_count.items()}
    # print(bigrams_prob)

    return {"unigram_count": unigram_count,
            "unigrams_prob": unigrams_prob,
            "bigram_count": bigram_count,
            "bigrams_prob": bigrams_prob}

# %%
# corp1 analysis
model_1 = ngrams_analysis(corpora_1)

# corp2 analysis
model_2 = ngrams_analysis(corpora_2)

# %%
import random

# %%
def generate(prompt:str, model:dict, max_tokens:int) -> str:

    for i in range(max_tokens):

        last_word = prompt.split()[-1]
        candidates = []
        probs = []

        for bigram,prob in model["bigrams_prob"].items():

            if bigram[0] == last_word:
                candidates.append(bigram[1])
                probs.append(prob)

        if not candidates:
            break

        total_prob = sum(probs)
        normalized_probs = [p/total_prob for p in probs]
        next_word = random.choices(candidates, weights=normalized_probs, k=1)[0]

        prompt += " " + next_word

    return prompt

# %%
import numpy as np

# %%
def perplexity(text: str, model: dict, smoothing_value = 1e-10) -> float:

    tokens = text.split()
    n = len(tokens)

    in_bigrams = [ (tokens[i], tokens[i+1]) for i in range(n-1) ]

    bigrams_prob = model["bigrams_prob"]

    in_probs = []

    for in_bigram in in_bigrams:

        if in_bigram in bigrams_prob:
            in_probs.append(bigrams_prob[in_bigram])
        else:
            in_probs.append(smoothing_value)

    in_probs = np.array(in_probs, dtype="float32")

    log_sum = np.sum(np.log(in_probs))
    perplexity = np.exp( -log_sum/n )

    return perplexity

# %%
model_1_generate = generate("محمد", model_1, max_tokens=50)
model_1_generate
# Out:
# 'محمد المهنا شكد اضوج ادخل تويتر شسوي لعد واحد شايف شي ميعجبني ما انتي اي ميخالف شوفني خل ايرفعوه وي مداستوعب اي شي تطلع فيمنست قبل صايره احب خصوصا بالاماكن الي راحو ونحجي عليهم كلهم طالعين لشغل ما عندنا عبالك طالعه من النتايج خلص وتذكرت ابنها لقصر واخذ اول شي واله'

# %%
perplexity(model_1_generate, model_1)
# Out:
# 11.969854419973643

# %%
model_2_generate = generate("محمد", model_2, max_tokens=50)
model_2_generate
# Out:
# 'محمد ليش الجذب كلشي مفتهمت منها هذا الحكي ما كواني مالي شغل احزاب اليمين المتطرف دا يتظاهرن لو نكول اشمانكول ما شاله واذا نريد نتخلص من تلبس ملابس شرطه هم بمدينه عراقيه وصداميه علي الردود تعرفهم تريد شي تهم ايران ليش الغيبه مثلا اي هزه خلي يرد عليك وعلي يوري البغل'

# %%
perplexity(model_2_generate, model_2)
# Out:
# 11.854948901283919

# %%
dict(sorted(model_1["unigram_count"].items(), key=lambda item: item[1], reverse=True))
# Out:
# {'من': 1037,
#  'ما': 740,
#  'بس': 649,
#  'الي': 596,
#  'مو': 564,
#  'علي': 483,
#  'اني': 376,
#  'واله': 360,
#  'اله': 358,
#  'ه': 301,
#  'لا': 289,
#  'لو': 266,
#  'يعني': 256,
#  'هذا': 247,
#  'هاي': 246,
#  'اي': 245,
#  'اذا': 237,
#  'شنو': 227,
#  'كل': 224,
#  'شي': 215,
#  'لان': 212,
#  'هو': 205,
#  'انت': 194,
#  'ليش': 194,
#  'حتي': 190,
#  'هسه': 189,
#  'واحد': 185,
#  'يا': 182,
#  'راح': 163,
#  'هيج': 160,
#  'هم': 148,
#  'او': 148,
#  'ولا': 143,
#  'ع': 142,
#  'بعد': 139,
#  'اكو': 120,
#  'انا': 117,
#  'بيه': 110,
#  'شلون': 109,
#  'وين': 108,
#  'في': 108,
#  'عن': 101,
#  'ان': 99,
#  'منو': 99,
#  'احنه': 98,
#  'عليه': 94,
#  'الناس': 94,
#  'ابو': 93,
#  'مثل': 92,
#  'العراق': 90,
#  'بيها': 89,
#  'مع': 88,
#  'ماكو': 88,
#  'عندي': 86,
#  'لازم': 84,
#  'مال': 84,
#  'صار': 83,
#  'كلش': 82,
#  'يوم': 80,
#  'و': 77,
#  'حلو': 76,
#  'هي': 75,
#  'اعرف': 74,
#  'غير': 74,
#  'يصير': 74,
#  'انتي': 74,
#  'انو': 70,
#  'مره': 69,
#  'قبل': 68,
#  'صح': 66,
#  'رح': 66,
#  'اليوم': 65,
#  'اول': 63,
#  'احد': 63,
#  'جان': 63,
#  'زين': 62,
#  'اكيد': 62,
#  'عنده': 61,
#  'عليك': 60,
#  'صدك': 59,
#  'بالعراق': 58,
#  'بدون': 58,
#  'اكثر': 58,
#  'هل': 57,
#  'اصلا': 57,
#  'كله': 56,
#  'وما': 56,
#  'ايران': 54,
#  'يكول': 54,
#  'ناس': 54,
#  'اريد': 54,
#  'سنه': 53,
#  'لعد': 53,
#  'ب': 53,
#  'خوش': 51,
#  'وحده': 50,
#  'مكن': 49,
#  'شاء': 48,
#  'نفس': 48,
#  'تري': 48,
#  'وانت': 47,
#  'بيهم': 46,
#  'ومن': 46,
#  'جنت': 46,
#  'انته': 46,
#  'لكن': 45,
#  'صارت': 45,
#  'احنا': 45,
#  'احب': 45,
#  'محد': 45,
#  'خير': 44,
#  'شكد': 44,
#  'هواي': 44,
#  'ربي': 43,
#  'هذه': 43,
#  'حلوه': 43,
#  'الف': 43,
#  'ويه': 43,
#  'كان': 42,
#  'صحيح': 42,
#  'عادي': 42,
#  'همه': 42,
#  'يارب': 42,
#  'اهل': 42,
#  'ادري': 42,
#  'الا': 41,
#  'جاي': 41,
#  'صاير': 41,
#  'خلي': 41,
#  'والي': 40,
#  'واني': 40,
#  'وانا': 40,
#  'هوايه': 40,
#  'منه': 39,
#  'له': 39,
#  'مدري': 39,
#  'شخص': 39,
#  'هنا': 39,
#  'وهو': 38,
#  'احلي': 38,
#  'تصير': 38,
#  'حبيبي': 38,
#  'شكرا': 37,
#  'تويتر': 37,
#  'عود': 37,
#  'هلا': 37,
#  'المفروض': 36,
#  'بكل': 36,
#  'صدام': 36,
#  'الان': 36,
#  'كلها': 36,
#  'اروح': 36,
#  'اشوف': 36,
#  'ترا': 36,
#  'بي': 36,
#  'يحجي': 36,
#  'هيه': 36,
#  'المشكله': 35,
#  'ابن': 35,
#  'لك': 35,
#  'احسن': 35,
#  'شكو': 35,
#  'انه': 34,
#  'يطلع': 34,
#  'شفت': 34,
#  'يلا': 34,
#  'ام': 34,
#  'يجي': 34,
#  'باجر': 34,
#  'يمكن': 33,
#  'صايره': 33,
#  'تره': 33,
#  'يكون': 33,
#  'بعدين': 33,
#  'طبعا': 33,
#  'عندك': 33,
#  'باله': 33,
#  'انتو': 33,
#  'عراقي': 32,
#  'عليكم': 32,
#  'العراقين': 32,
#  'فدوه': 32,
#  'ايام': 32,
#  'لحد': 31,
#  'الك': 31,
#  'عليهم': 31,
#  'عيني': 31,
#  'خل': 30,
#  'شويه': 30,
#  'العالم': 30,
#  'داعش': 30,
#  'كلام': 30,
#  'ال': 30,
#  'ها': 30,
#  'طلع': 30,
#  'حيل': 30,
#  'ل': 30,
#  'واذا': 30,
#  'احجي': 30,
#  'بغداد': 30,
#  'المهم': 30,
#  'وكل': 30,
#  'الشعب': 29,
#  'شوف': 29,
#  'منك': 29,
#  'احس': 29,
#  'قلبي': 29,
#  'الصبح': 29,
#  'ساعه': 29,
#  'اهم': 29,
#  'بيك': 28,
#  'شو': 28,
#  'عليها': 28,
#  'كلت': 28,
#  'كلهم': 27,
#  'ماعرف': 27,
#  'ابد': 27,
#  'الخير': 27,
#  'تكون': 27,
#  'فلوس': 27,
#  'البنات': 27,
#  'امي': 27,
#  'بالعكس': 26,
#  'دا': 26,
#  'ولد': 26,
#  'اخر': 26,
#  'كافي': 26,
#  'سالفه': 26,
#  'تطلع': 26,
#  'يشوف': 25,
#  'اسمه': 25,
#  'كلشي': 25,
#  'روحي': 25,
#  'بين': 25,
#  'محمد': 24,
#  'جدا': 24,
#  'بخير': 24,
#  'نفسه': 24,
#  'الكل': 24,
#  'الكلام': 24,
#  'لي': 24,
#  'خطيه': 24,
#  'فد': 24,
#  'عدنه': 23,
#  'فتره': 23,
#  'علينا': 23,
#  'كلبي': 23,
#  'اكول': 23,
#  'اكره': 23,
#  'موجود': 23,
#  'يعرف': 23,
#  'عبالك': 23,
#  'الدنيا': 23,
#  'حته': 23,
#  'يم': 22,
#  'عام': 22,
#  'تعرف': 22,
#  'عرفت': 22,
#  'تحجي': 22,
#  'مكان': 22,
#  'ف': 22,
#  'مستحيل': 22,
#  'وياه': 22,
#  'وياي': 22,
#  'اكدر': 22,
#  'انشاله': 22,
#  'عمي': 21,
#  'كم': 21,
#  'العمر': 21,
#  'ولو': 21,
#  'بيكم': 21,
#  'كلامك': 21,
#  'يروح': 21,
#  'يكولون': 21,
#  'علاقه': 21,
#  'سنين': 21,
#  'وقت': 21,
#  'ويا': 21,
#  'شوكت': 21,
#  'تجي': 21,
#  'مثلا': 21,
#  'العرب': 20,
#  'طيب': 20,
#  'شوفي': 20,
#  'الدين': 20,
#  'السنه': 20,
#  'يستاهل': 20,
#  'اعتقد': 20,
#  'عدهم': 20,
#  'دكتور': 20,
#  'انتم': 20,
#  'موجوده': 20,
#  'السالفه': 20,
#  'وي': 20,
#  'جانت': 20,
#  'عندهم': 20,
#  'وياك': 20,
#  'باب': 19,
#  'جماعه': 19,
#  'وهذا': 19,
#  'استاذ': 19,
#  'كنت': 19,
#  'مشكله': 19,
#  'شعب': 19,
#  'وبعدين': 19,
#  'قابل': 19,
#  'غلط': 19,
#  'اساس': 19,
#  'السعوديه': 19,
#  'مادري': 19,
#  'العراقي': 19,
#  'طلعت': 19,
#  'مرات': 19,
#  'يبارك': 19,
#  'وهم': 19,
#  'هالشي': 19,
#  'وانتي': 19,
#  'ذوق': 19,
#  'العين': 19,
#  'يمه': 19,
#  'الحلوه': 18,
#  'سءال': 18,
#  'الجماعه': 18,
#  'التغريده': 18,
#  'البارحه': 18,
#  'مني': 18,
#  'منهم': 18,
#  'كلمه': 18,
#  'منين': 18,
#  'شنسوي': 18,
#  'اصير': 18,
#  'البلد': 18,
#  'ورا': 18,
#  'علمود': 18,
#  'دوله': 18,
#  'حب': 18,
#  'اقصد': 18,
#  'موضوع': 18,
#  'الشي': 18,
#  'بلوك': 18,
#  'كبير': 18,
#  'يريد': 18,
#  'اكبر': 18,
#  'عيد': 18,
#  'صباح': 18,
#  'امك': 18,
#  'راس': 18,
#  'يابه': 18,
#  'حظ': 18,
#  'بلد': 17,
#  'داءما': 17,
#  'يحب': 17,
#  'وهسه': 17,
#  'اخي': 17,
#  'شوي': 17,
#  'فقط': 17,
#  'الاسف': 17,
#  'اتمني': 17,
#  'واضح': 17,
#  'اجي': 17,
#  'زينه': 17,
#  'بنات': 17,
#  'لما': 17,
#  'نفسي': 17,
#  'اسم': 17,
#  'كاعد': 17,
#  'ماله': 17,
#  'الصدر': 17,
#  'عفيه': 17,
#  'بابا': 17,
#  'اوكي': 17,
#  'ومنو': 16,
#  'وعلي': 16,
#  'امين': 16,
#  'يوميه': 16,
#  'امريكا': 16,
#  'علينه': 16,
#  'بحياتي': 16,
#  'لعراق': 16,
#  'شهر': 16,
#  'طول': 16,
#  'يقول': 16,
#  'بتويتر': 16,
#  'عمري': 16,
#  'اسوي': 16,
#  'نشوف': 16,
#  'عليج': 16,
#  'بالي': 16,
#  'حساب': 16,
#  'مرحله': 16,
#  'ثاني': 16,
#  'تشوف': 16,
#  'وصلت': 16,
#  'البيت': 16,
#  'الولد': 16,
#  'اشلون': 16,
#  'بيا': 16,
#  'فعلا': 16,
#  'عاشت': 16,
#  'اخ': 15,
#  'خلص': 15,
#  'يسعد': 15,
#  'وره': 15,
#  'واحنه': 15,
#  'بالف': 15,
#  'يبقي': 15,
#  'اخاف': 15,
#  'انسان': 15,
#  'كيف': 15,
#  'عند': 15,
#  'مات': 15,
#  'عندنا': 15,
#  'اشو': 15,
#  'زمان': 15,
#  'موت': 15,
#  'اكل': 15,
#  'بعض': 15,
#  'وياهم': 15,
#  'ذاك': 15,
#  'بيج': 15,
#  'اشوفه': 15,
#  'اسمي': 15,
#  'يومين': 15,
#  'ايدك': 15,
#  'نص': 15,
#  'عمر': 15,
#  'روح': 15,
#  'عيب': 15,
#  'ثانيه': 15,
#  'شغل': 15,
#  'خرب': 15,
#  'ياخي': 14,
#  'رجل': 14,
#  'بنت': 14,
#  'انك': 14,
#  'مبروك': 14,
#  'الصوره': 14,
#  'مبارك': 14,
#  'حبيبتي': 14,
#  'مصيبه': 14,
#  'المالكي': 14,
#  'شلونك': 14,
#  'عمل': 14,
#  'قال': 14,
#  'العلم': 14,
#  'عبد': 14,
#  'اغلب': 14,
#  'اما': 14,
#  'الحب': 14,
#  'اوفر': 14,
#  'وليش': 14,
#  'يمي': 14,
#  'بالبيت': 14,
#  'حرام': 14,
#  'عيوني': 14,
#  'تروح': 14,
#  'سب': 14,
#  'بينا': 14,
#  'فوك': 14,
#  'بسب': 14,
#  'اخوي': 14,
#  'يمعوده': 14,
#  'كال': 14,
#  'لابو': 14,
#  'تدري': 14,
#  'اهلا': 14,
#  'ذوله': 14,
#  'ورده': 14,
#  'ماعندي': 13,
#  'شيء': 13,
#  'اتفق': 13,
#  'حسين': 13,
#  'كلامي': 13,
#  'حاله': 13,
#  'عمرك': 13,
#  'يمعود': 13,
#  'اطلع': 13,
#  'حر': 13,
#  'الحكومه': 13,
#  'دوم': 13,
#  'كلمن': 13,
#  'چا': 13,
#  'چان': 13,
#  'ضد': 13,
#  'نفسهم': 13,
#  'يجوز': 13,
#  'راحت': 13,
#  'وكت': 13,
#  'كميه': 13,
#  'راي': 13,
#  'مجرد': 13,
#  'الحياه': 13,
#  'ايه': 13,
#  'وبس': 13,
#  'اسمع': 13,
#  'تسوي': 13,
#  'تسلم': 13,
#  'داعي': 13,
#  'يحفظك': 13,
#  'صراحه': 13,
#  'المراه': 13,
#  'تريد': 13,
#  'الهم': 13,
#  'حل': 13,
#  'خله': 13,
#  'يسوي': 13,
#  'عمو': 13,
#  'هله': 13,
#  'المناكحه': 13,
#  'فيك': 13,
#  'منون': 13,
#  'م': 13,
#  'رحمه': 12,
#  'الموضوع': 12,
#  'منها': 12,
#  'السوالف': 12,
#  'ايدي': 12,
#  'صعبه': 12,
#  'حكومه': 12,
#  'عايش': 12,
#  'اتوقع': 12,
#  'بقت': 12,
#  'عايشين': 12,
#  'اشوفك': 12,
#  'شسوي': 12,
#  'شايف': 12,
#  'شفته': 12,
#  'الوضع': 12,
#  'غيره': 12,
#  'بدال': 12,
#  'مسوي': 12,
#  'وراها': 12,
#  'لمن': 12,
#  'وياج': 12,
#  'اختك': 12,
#  'عدها': 12,
#  'الجو': 12,
#  'نسوي': 12,
#  'كلنا': 12,
#  'حبيت': 12,
#  'حسابك': 12,
#  'كثر': 12,
#  'اقل': 12,
#  'بالشارع': 12,
#  'اسراءيل': 12,
#  'ديالي': 12,
#  'رجال': 12,
#  'عاد': 12,
#  'اتذكر': 12,
#  'عنه': 12,
#  'اخذ': 12,
#  'كون': 12,
#  'الدوله': 12,
#  'روحه': 12,
#  'ي': 12,
#  'ويانه': 12,
#  'جهاد': 12,
#  'البشر': 11,
#  'صرت': 11,
#  'العيد': 11,
#  'حق': 11,
#  'الاخ': 11,
#  'طلعوا': 11,
#  'سويت': 11,
#  'رءيس': 11,
#  'جديد': 11,
#  'مثلك': 11,
#  'كانت': 11,
#  'افكر': 11,
#  'الجمعه': 11,
#  'جديده': 11,
#  'الوكت': 11,
#  'عنها': 11,
#  'يرحمه': 11,
#  'رمضان': 11,
#  'الورد': 11,
#  'ارجع': 11,
#  'اسبوع': 11,
#  'الايام': 11,
#  'يحجون': 11,
#  'احبه': 11,
#  'جاد': 11,
#  'باي': 11,
#  'مهم': 11,
#  'وهي': 11,
#  'صوره': 11,
#  'ضحك': 11,
#  'الوقت': 11,
#  'عليا': 11,
#  'وراه': 11,
#  'كره': 11,
#  'قليل': 11,
#  'هناك': 11,
#  'الشغله': 11,
#  'شغله': 11,
#  'لكل': 11,
#  'طلاب': 11,
#  'تحس': 11,
#  'بنفس': 11,
#  'رغم': 11,
#  'تغريده': 11,
#  'اجمل': 11,
#  'افضل': 11,
#  'وراح': 11,
#  'حال': 11,
#  'امام': 11,
#  'وحتي': 11,
#  'السيد': 11,
#  'يكلك': 11,
#  'بصراحه': 11,
#  'زيد': 11,
#  'تحياتي': 11,
#  'العافيه': 11,
#  'اموت': 11,
#  'ابويه': 11,
#  'ضروري': 11,
#  'شكلي': 11,
#  'بنيه': 11,
#  'تسلميلي': 11,
#  'ضلعي': 11,
#  'ردت': 10,
#  'معك': 10,
#  'سيد': 10,
#  'ياله': 10,
#  'نعمه': 10,
#  'تضحك': 10,
#  'قلت': 10,
#  'وانتم': 10,
#  'طبيعي': 10,
#  'خاف': 10,
#  'نفسيه': 10,
#  'هلو': 10,
#  'وينه': 10,
#  'ساعات': 10,
#  'الواحد': 10,
#  'مليون': 10,
#  'ومو': 10,
#  'ابدا': 10,
#  'البصره': 10,
#  'قويه': 10,
#  'اعرفه': 10,
#  'القلب': 10,
#  'بالنسبه': 10,
#  'روحك': 10,
#  'جميل': 10,
#  'طاءفي': 10,
#  'هوايا': 10,
#  'سمعت': 10,
#  'صارلي': 10,
#  'تقريبا': 10,
#  'عل': 10,
#  'بالك': 10,
#  'تغير': 10,
#  'الجنه': 10,
#  'يمنا': 10,
#  'ميعرف': 10,
#  'البنيه': 10,
#  'ولازم': 10,
#  'يردون': 10,
#  'لكم': 10,
#  'ورد': 10,
#  'نحجي': 10,
#  'فيها': 10,
#  'فكر': 10,
#  'الحر': 10,
#  'عبالي': 10,
#  'حظه': 10,
#  'نايم': 10,
#  'اقوي': 10,
#  'عربيه': 10,
#  'فرق': 10,
#  'الكهرباء': 10,
#  'خاص': 10,
#  'مالي': 10,
#  'الغلط': 10,
#  'ليل': 10,
#  'بعيد': 10,
#  'شر': 10,
#  'لغه': 10,
#  'رحت': 10,
#  'عراقيه': 10,
#  'هيچ': 10,
#  'النفس': 10,
#  'يله': 10,
#  'اخويه': 10,
#  'رجعت': 10,
#  'كومه': 10,
#  'زينب': 10,
#  'اضحك': 10,
#  'احبك': 10,
#  'الذوق': 10,
#  'عنك': 9,
#  'اخوه': 9,
#  'بشر': 9,
#  'لها': 9,
#  'فيه': 9,
#  'ياخذ': 9,
#  'الصور': 9,
#  'اطفال': 9,
#  'تكلم': 9,
#  'منونه': 9,
#  'الرجال': 9,
#  'ينعاد': 9,
#  'البال': 9,
#  'وربي': 9,
#  'بينه': 9,
#  'الشيعه': 9,
#  'العربيه': 9,
#  'ابوك': 9,
#  'بسرعه': 9,
#  'خبر': 9,
#  'الثانيه': 9,
#  'علم': 9,
#  'الخبر': 9,
#  'انوب': 9,
#  'رايحه': 9,
#  'الزواج': 9,
#  'البعض': 9,
#  'يحتاج': 9,
#  'واكو': 9,
#  'تعبانه': 9,
#  'النور': 9,
#  'معقوله': 9,
#  'طاح': 9,
#  'ادور': 9,
#  'دكتوره': 9,
#  'شكل': 9,
#  'عمره': 9,
#  'عربي': 9,
#  'طويله': 9,
#  'حسيت': 9,
#  'لانه': 9,
#  'باسم': 9,
#  'طالب': 9,
#  'خطا': 9,
#  'السب': 9,
#  'عني': 9,
#  'رد': 9,
#  'منشن': 9,
#  'حزب': 9,
#  'بحياتك': 9,
#  'طالعه': 9,
#  'طفل': 9,
#  'باليل': 9,
#  'خصوصا': 9,
#  'الغالي': 9,
#  'خلك': 9,
#  'انام': 9,
#  'وشنو': 9,
#  'الانستا': 9,
#  'مي': 9,
#  'ايده': 9,
#  'الانبار': 9,
#  'شايفه': 9,
#  'شباب': 9,
#  'كلب': 9,
#  'دوام': 9,
#  'عطله': 9,
#  'اقول': 9,
#  'البنت': 9,
#  'تخيل': 9,
#  'بلا': 9,
#  'ساره': 9,
#  'نسيت': 9,
#  'امتحان': 9,
#  'كلكم': 9,
#  'برنامج': 9,
#  'اكله': 9,
#  'كاظم': 9,
#  'عندج': 9,
#  'الحشد': 9,
#  'الكبير': 9,
#  'احمد': 9,
#  'عيون': 9,
#  'بلكي': 9,
#  'مسويه': 9,
#  'كيوت': 9,
#  'ذوقج': 9,
#  'اهلي': 9,
#  'مالتي': 9,
#  'وش': 9,
#  'الج': 9,
#  'هالمره': 9,
#  'مشاكل': 8,
#  'معه': 8,
#  'اولا': 8,
#  'وحدي': 8,
#  'يرجع': 8,
#  'منا': 8,
#  'بالبصره': 8,
#  'الظاهر': 8,
#  'شخصيه': 8,
#  'غريب': 8,
#  'بهاي': 8,
#  'بقي': 8,
#  'لهذا': 8,
#  'ومحد': 8,
#  'مقصوده': 8,
#  'وربك': 8,
#  'النسوان': 8,
#  'هذوله': 8,
#  'بغير': 8,
#  'لايك': 8,
#  'بعده': 8,
#  'الثاني': 8,
#  'مساء': 8,
#  'بعيده': 8,
#  'الرجل': 8,
#  'انطيك': 8,
#  'يديم': 8,
#  'شفتها': 8,
#  'العيون': 8,
#  'دخل': 8,
#  'فكره': 8,
#  'الامور': 8,
#  'لدرجه': 8,
#  'سوالف': 8,
#  'عجيب': 8,
#  'حكومتنا': 8,
#  'باقي': 8,
#  'امه': 8,
#  'همزين': 8,
#  'ويصير': 8,
#  'ياريت': 8,
#  'صفحه': 8,
#  'وجه': 8,
#  'استغفر': 8,
#  'عادل': 8,
#  'شكلك': 8,
#  'توصل': 8,
#  'خويه': 8,
#  'تويت': 8,
#  'اسال': 8,
#  'خارج': 8,
#  'صديقه': 8,
#  'بوجه': 8,
#  'صديقتي': 8,
#  'رجع': 8,
#  'ونص': 8,
#  'قمه': 8,
#  'يسون': 8,
#  'اوي': 8,
#  'العام': 8,
#  'ارد': 8,
#  'الها': 8,
#  'خاصه': 8,
#  'قريب': 8,
#  'جذب': 8,
#  'يشتغل': 8,
#  'وانتو': 8,
#  'حسب': 8,
#  'عبر': 8,
#  'بالضبط': 8,
#  'لذلك': 8,
#  'كامل': 8,
#  'شبيك': 8,
#  'احترام': 8,
#  'النت': 8,
#  'شعور': 8,
#  'بيت': 8,
#  'شعر': 8,
#  'غيرك': 8,
#  'حاليا': 8,
#  'نكول': 8,
#  'كريم': 8,
#  'تعب': 8,
#  'فرح': 8,
#  'منكم': 8,
#  'رساله': 8,
#  'اغاني': 8,
#  'خليها': 8,
#  'حشاك': 8,
#  'مالها': 8,
#  'تاكل': 8,
#  'اشياء': 8,
#  'تجيب': 8,
#  'قوي': 8,
#  'الفيس': 8,
#  'واعرف': 8,
#  'تستاهل': 8,
#  'منوع': 8,
#  'راتب': 8,
#  'المجتمع': 8,
#  'ريال': 8,
#  'براسي': 8,
#  'ميصير': 8,
#  'خو': 8,
#  'الاول': 8,
#  'الحجي': 8,
#  'وضع': 8,
#  'مناسبه': 8,
#  'المثل': 8,
#  'بال': 8,
#  'حسابي': 8,
#  'اخلي': 8,
#  'مقتدي': 8,
#  'سوه': 8,
#  'ضايجه': 8,
#  'الناصريه': 8,
#  'مليان': 8,
#  'جا': 8,
#  'يكلي': 8,
#  'رب': 8,
#  'فايده': 8,
#  'اصدقاءي': 8,
#  'اغنيه': 8,
#  'وهمه': 8,
#  'حياتي': 8,
#  'يزيد': 8,
#  'شعري': 8,
#  'عدنا': 8,
#  'قلب': 8,
#  'يرضي': 7,
#  'خلصت': 7,
#  'كلك': 7,
#  'ماخذ': 7,
#  'عباله': 7,
#  'ريحه': 7,
#  'سبحان': 7,
#  'يخاف': 7,
#  'الغاليه': 7,
#  'صاحب': 7,
#  'شبيه': 7,
#  'بالعافيه': 7,
#  'صحه': 7,
#  'قسم': 7,
#  'تحت': 7,
#  'تبين': 7,
#  'نوري': 7,
#  'لسانك': 7,
#  'التغير': 7,
#  'الشرف': 7,
#  'ضحكتني': 7,
#  'راسي': 7,
#  'يجون': 7,
#  'يشوفون': 7,
#  'لابس': 7,
#  'فوق': 7,
#  'راسك': 7,
#  'المهدي': 7,
#  'كفو': 7,
#  'قديمه': 7,
#  'فلان': 7,
#  'صعب': 7,
#  'چاي': 7,
#  'صارله': 7,
#  'اسود': 7,
#  'صاحبه': 7,
#  'احترامي': 7,
#  'يخليك': 7,
#  'جو': 7,
#  'كبيره': 7,
#  'وزير': 7,
#  'خليه': 7,
#  'شيخ': 7,
#  'بهل': 7,
#  'قرار': 7,
#  'شاءاله': 7,
#  'قريت': 7,
#  'صديق': 7,
#  'مسلسل': 7,
#  'بنص': 7,
#  'الشباب': 7,
#  'بطل': 7,
#  'مثال': 7,
#  'دخلت': 7,
#  'بعدني': 7,
#  'مت': 7,
#  'تشوفه': 7,
#  'متاكده': 7,
#  'بالفعل': 7,
#  'الامريكان': 7,
#  'يطلعون': 7,
#  'جايه': 7,
#  'بشي': 7,
#  'كدام': 7,
#  'كد': 7,
#  'بهذا': 7,
#  'اوف': 7,
#  'برا': 7,
#  'طريقه': 7,
#  'اب': 7,
#  'شغلات': 7,
#  'جوه': 7,
#  'اخذت': 7,
#  'وياكم': 7,
#  'يجيبون': 7,
#  'ابقي': 7,
#  'سو': 7,
#  'منج': 7,
#  'تاخذ': 7,
#  'الاكل': 7,
#  'نفسك': 7,
#  'سياسه': 7,
#  'ثلاث': 7,
#  'تعبان': 7,
#  'صور': 7,
#  'عندها': 7,
#  'نسوان': 7,
#  'حجي': 7,
#  ...}

# %%
dict(sorted(model_1["unigrams_prob"].items(), key=lambda item: item[1], reverse=True))
# Out:
# {'من': 0.018484189511960358,
#  'ما': 0.013190260596770169,
#  'بس': 0.01156821503689708,
#  'الي': 0.010623507183344622,
#  'مو': 0.010053117535916723,
#  'علي': 0.008609318740864853,
#  'اني': 0.006702078357277815,
#  'واله': 0.006416883533563866,
#  'اله': 0.0063812341805996224,
#  'ه': 0.005365227621118677,
#  'لا': 0.005151331503333215,
#  'لو': 0.004741363944244412,
#  'يعني': 0.0045631171794231935,
#  'هذا': 0.004402695091084097,
#  'هاي': 0.004384870414601975,
#  'اي': 0.004367045738119853,
#  'اذا': 0.004224448326262878,
#  'شنو': 0.00404620156144166,
#  'كل': 0.003992727531995294,
#  'شي': 0.0038323054436561975,
#  'لان': 0.003778831414209832,
#  'هو': 0.003654058678834979,
#  'انت': 0.003457987237531639,
#  'ليش': 0.003457987237531639,
#  'حتي': 0.0033866885316031514,
#  'هسه': 0.0033688638551210297,
#  'واحد': 0.003297565149192542,
#  'يا': 0.0032440911197461767,
#  'راح': 0.0029054222665858614,
#  'هيج': 0.002851948237139496,
#  'هم': 0.0026380521193540337,
#  'او': 0.0026380521193540337,
#  'ولا': 0.0025489287369434245,
#  'ع': 0.002531104060461303,
#  'بعد': 0.002477630031014937,
#  'اكو': 0.002138961177854622,
#  'انا': 0.002085487148408256,
#  'بيه': 0.0019607144130334036,
#  'شلون': 0.0019428897365512815,
#  'وين': 0.0019250650600691598,
#  'في': 0.0019250650600691598,
#  'عن': 0.0018002923246943068,
#  'ان': 0.001764642971730063,
#  'منو': 0.001764642971730063,
#  'احنه': 0.0017468182952479414,
#  'عليه': 0.0016755195893194538,
#  'الناس': 0.0016755195893194538,
#  'ابو': 0.001657694912837332,
#  'مثل': 0.0016398702363552102,
#  'العراق': 0.0016042208833909664,
#  'بيها': 0.0015863962069088446,
#  'مع': 0.0015685715304267227,
#  'ماكو': 0.0015685715304267227,
#  'عندي': 0.001532922177462479,
#  'لازم': 0.0014972728244982353,
#  'مال': 0.0014972728244982353,
#  'صار': 0.0014794481480161134,
#  'كلش': 0.0014616234715339918,
#  'يوم': 0.001425974118569748,
#  'و': 0.0013725000891233823,
#  'حلو': 0.0013546754126412606,
#  'هي': 0.0013368507361591387,
#  'اعرف': 0.0013190260596770169,
#  'غير': 0.0013190260596770169,
#  'يصير': 0.0013190260596770169,
#  'انتي': 0.0013190260596770169,
#  'انو': 0.0012477273537485295,
#  'مره': 0.0012299026772664076,
#  'قبل': 0.0012120780007842857,
#  'صح': 0.0011764286478200422,
#  'رح': 0.0011764286478200422,
#  'اليوم': 0.0011586039713379203,
#  'اول': 0.0011229546183736765,
#  'احد': 0.0011229546183736765,
#  'جان': 0.0011229546183736765,
#  'زين': 0.0011051299418915546,
#  'اكيد': 0.0011051299418915546,
#  'عنده': 0.0010873052654094327,
#  'عليك': 0.001069480588927311,
#  'صدك': 0.0010516559124451891,
#  'بالعراق': 0.0010338312359630673,
#  'بدون': 0.0010338312359630673,
#  'اكثر': 0.0010338312359630673,
#  'هل': 0.0010160065594809454,
#  'اصلا': 0.0010160065594809454,
#  'كله': 0.0009981818829988235,
#  'وما': 0.0009981818829988235,
#  'ايران': 0.0009625325300345799,
#  'يكول': 0.0009625325300345799,
#  'ناس': 0.0009625325300345799,
#  'اريد': 0.0009625325300345799,
#  'سنه': 0.000944707853552458,
#  'لعد': 0.000944707853552458,
#  'ب': 0.000944707853552458,
#  'خوش': 0.0009090585005882143,
#  'وحده': 0.0008912338241060925,
#  'مكن': 0.0008734091476239707,
#  'شاء': 0.0008555844711418488,
#  'نفس': 0.0008555844711418488,
#  'تري': 0.0008555844711418488,
#  'وانت': 0.0008377597946597269,
#  'بيهم': 0.0008199351181776051,
#  'ومن': 0.0008199351181776051,
#  'جنت': 0.0008199351181776051,
#  'انته': 0.0008199351181776051,
#  'لكن': 0.0008021104416954832,
#  'صارت': 0.0008021104416954832,
#  'احنا': 0.0008021104416954832,
#  'احب': 0.0008021104416954832,
#  'محد': 0.0008021104416954832,
#  'خير': 0.0007842857652133613,
#  'شكد': 0.0007842857652133613,
#  'هواي': 0.0007842857652133613,
#  'ربي': 0.0007664610887312396,
#  'هذه': 0.0007664610887312396,
#  'حلوه': 0.0007664610887312396,
#  'الف': 0.0007664610887312396,
#  'ويه': 0.0007664610887312396,
#  'كان': 0.0007486364122491177,
#  'صحيح': 0.0007486364122491177,
#  'عادي': 0.0007486364122491177,
#  'همه': 0.0007486364122491177,
#  'يارب': 0.0007486364122491177,
#  'اهل': 0.0007486364122491177,
#  'ادري': 0.0007486364122491177,
#  'الا': 0.0007308117357669959,
#  'جاي': 0.0007308117357669959,
#  'صاير': 0.0007308117357669959,
#  'خلي': 0.0007308117357669959,
#  'والي': 0.000712987059284874,
#  'واني': 0.000712987059284874,
#  'وانا': 0.000712987059284874,
#  'هوايه': 0.000712987059284874,
#  'منه': 0.0006951623828027521,
#  'له': 0.0006951623828027521,
#  'مدري': 0.0006951623828027521,
#  'شخص': 0.0006951623828027521,
#  'هنا': 0.0006951623828027521,
#  'وهو': 0.0006773377063206303,
#  'احلي': 0.0006773377063206303,
#  'تصير': 0.0006773377063206303,
#  'حبيبي': 0.0006773377063206303,
#  'شكرا': 0.0006595130298385084,
#  'تويتر': 0.0006595130298385084,
#  'عود': 0.0006595130298385084,
#  'هلا': 0.0006595130298385084,
#  'المفروض': 0.0006416883533563865,
#  'بكل': 0.0006416883533563865,
#  'صدام': 0.0006416883533563865,
#  'الان': 0.0006416883533563865,
#  'كلها': 0.0006416883533563865,
#  'اروح': 0.0006416883533563865,
#  'اشوف': 0.0006416883533563865,
#  'ترا': 0.0006416883533563865,
#  'بي': 0.0006416883533563865,
#  'يحجي': 0.0006416883533563865,
#  'هيه': 0.0006416883533563865,
#  'المشكله': 0.0006238636768742648,
#  'ابن': 0.0006238636768742648,
#  'لك': 0.0006238636768742648,
#  'احسن': 0.0006238636768742648,
#  'شكو': 0.0006238636768742648,
#  'انه': 0.0006060390003921429,
#  'يطلع': 0.0006060390003921429,
#  'شفت': 0.0006060390003921429,
#  'يلا': 0.0006060390003921429,
#  'ام': 0.0006060390003921429,
#  'يجي': 0.0006060390003921429,
#  'باجر': 0.0006060390003921429,
#  'يمكن': 0.0005882143239100211,
#  'صايره': 0.0005882143239100211,
#  'تره': 0.0005882143239100211,
#  'يكون': 0.0005882143239100211,
#  'بعدين': 0.0005882143239100211,
#  'طبعا': 0.0005882143239100211,
#  'عندك': 0.0005882143239100211,
#  'باله': 0.0005882143239100211,
#  'انتو': 0.0005882143239100211,
#  'عراقي': 0.0005703896474278992,
#  'عليكم': 0.0005703896474278992,
#  'العراقين': 0.0005703896474278992,
#  'فدوه': 0.0005703896474278992,
#  'ايام': 0.0005703896474278992,
#  'لحد': 0.0005525649709457773,
#  'الك': 0.0005525649709457773,
#  'عليهم': 0.0005525649709457773,
#  'عيني': 0.0005525649709457773,
#  'خل': 0.0005347402944636555,
#  'شويه': 0.0005347402944636555,
#  'العالم': 0.0005347402944636555,
#  'داعش': 0.0005347402944636555,
#  'كلام': 0.0005347402944636555,
#  'ال': 0.0005347402944636555,
#  'ها': 0.0005347402944636555,
#  'طلع': 0.0005347402944636555,
#  'حيل': 0.0005347402944636555,
#  'ل': 0.0005347402944636555,
#  'واذا': 0.0005347402944636555,
#  'احجي': 0.0005347402944636555,
#  'بغداد': 0.0005347402944636555,
#  'المهم': 0.0005347402944636555,
#  'وكل': 0.0005347402944636555,
#  'الشعب': 0.0005169156179815336,
#  'شوف': 0.0005169156179815336,
#  'منك': 0.0005169156179815336,
#  'احس': 0.0005169156179815336,
#  'قلبي': 0.0005169156179815336,
#  'الصبح': 0.0005169156179815336,
#  'ساعه': 0.0005169156179815336,
#  'اهم': 0.0005169156179815336,
#  'بيك': 0.0004990909414994117,
#  'شو': 0.0004990909414994117,
#  'عليها': 0.0004990909414994117,
#  'كلت': 0.0004990909414994117,
#  'كلهم': 0.00048126626501728996,
#  'ماعرف': 0.00048126626501728996,
#  'ابد': 0.00048126626501728996,
#  'الخير': 0.00048126626501728996,
#  'تكون': 0.00048126626501728996,
#  'فلوس': 0.00048126626501728996,
#  'البنات': 0.00048126626501728996,
#  'امي': 0.00048126626501728996,
#  'بالعكس': 0.00046344158853516807,
#  'دا': 0.00046344158853516807,
#  'ولد': 0.00046344158853516807,
#  'اخر': 0.00046344158853516807,
#  'كافي': 0.00046344158853516807,
#  'سالفه': 0.00046344158853516807,
#  'تطلع': 0.00046344158853516807,
#  'يشوف': 0.00044561691205304623,
#  'اسمه': 0.00044561691205304623,
#  'كلشي': 0.00044561691205304623,
#  'روحي': 0.00044561691205304623,
#  'بين': 0.00044561691205304623,
#  'محمد': 0.0004277922355709244,
#  'جدا': 0.0004277922355709244,
#  'بخير': 0.0004277922355709244,
#  'نفسه': 0.0004277922355709244,
#  'الكل': 0.0004277922355709244,
#  'الكلام': 0.0004277922355709244,
#  'لي': 0.0004277922355709244,
#  'خطيه': 0.0004277922355709244,
#  'فد': 0.0004277922355709244,
#  'عدنه': 0.00040996755908880256,
#  'فتره': 0.00040996755908880256,
#  'علينا': 0.00040996755908880256,
#  'كلبي': 0.00040996755908880256,
#  'اكول': 0.00040996755908880256,
#  'اكره': 0.00040996755908880256,
#  'موجود': 0.00040996755908880256,
#  'يعرف': 0.00040996755908880256,
#  'عبالك': 0.00040996755908880256,
#  'الدنيا': 0.00040996755908880256,
#  'حته': 0.00040996755908880256,
#  'يم': 0.00039214288260668067,
#  'عام': 0.00039214288260668067,
#  'تعرف': 0.00039214288260668067,
#  'عرفت': 0.00039214288260668067,
#  'تحجي': 0.00039214288260668067,
#  'مكان': 0.00039214288260668067,
#  'ف': 0.00039214288260668067,
#  'مستحيل': 0.00039214288260668067,
#  'وياه': 0.00039214288260668067,
#  'وياي': 0.00039214288260668067,
#  'اكدر': 0.00039214288260668067,
#  'انشاله': 0.00039214288260668067,
#  'عمي': 0.00037431820612455883,
#  'كم': 0.00037431820612455883,
#  'العمر': 0.00037431820612455883,
#  'ولو': 0.00037431820612455883,
#  'بيكم': 0.00037431820612455883,
#  'كلامك': 0.00037431820612455883,
#  'يروح': 0.00037431820612455883,
#  'يكولون': 0.00037431820612455883,
#  'علاقه': 0.00037431820612455883,
#  'سنين': 0.00037431820612455883,
#  'وقت': 0.00037431820612455883,
#  'ويا': 0.00037431820612455883,
#  'شوكت': 0.00037431820612455883,
#  'تجي': 0.00037431820612455883,
#  'مثلا': 0.00037431820612455883,
#  'العرب': 0.000356493529642437,
#  'طيب': 0.000356493529642437,
#  'شوفي': 0.000356493529642437,
#  'الدين': 0.000356493529642437,
#  'السنه': 0.000356493529642437,
#  'يستاهل': 0.000356493529642437,
#  'اعتقد': 0.000356493529642437,
#  'عدهم': 0.000356493529642437,
#  'دكتور': 0.000356493529642437,
#  'انتم': 0.000356493529642437,
#  'موجوده': 0.000356493529642437,
#  'السالفه': 0.000356493529642437,
#  'وي': 0.000356493529642437,
#  'جانت': 0.000356493529642437,
#  'عندهم': 0.000356493529642437,
#  'وياك': 0.000356493529642437,
#  'باب': 0.00033866885316031516,
#  'جماعه': 0.00033866885316031516,
#  'وهذا': 0.00033866885316031516,
#  'استاذ': 0.00033866885316031516,
#  'كنت': 0.00033866885316031516,
#  'مشكله': 0.00033866885316031516,
#  'شعب': 0.00033866885316031516,
#  'وبعدين': 0.00033866885316031516,
#  'قابل': 0.00033866885316031516,
#  'غلط': 0.00033866885316031516,
#  'اساس': 0.00033866885316031516,
#  'السعوديه': 0.00033866885316031516,
#  'مادري': 0.00033866885316031516,
#  'العراقي': 0.00033866885316031516,
#  'طلعت': 0.00033866885316031516,
#  'مرات': 0.00033866885316031516,
#  'يبارك': 0.00033866885316031516,
#  'وهم': 0.00033866885316031516,
#  'هالشي': 0.00033866885316031516,
#  'وانتي': 0.00033866885316031516,
#  'ذوق': 0.00033866885316031516,
#  'العين': 0.00033866885316031516,
#  'يمه': 0.00033866885316031516,
#  'الحلوه': 0.00032084417667819327,
#  'سءال': 0.00032084417667819327,
#  'الجماعه': 0.00032084417667819327,
#  'التغريده': 0.00032084417667819327,
#  'البارحه': 0.00032084417667819327,
#  'مني': 0.00032084417667819327,
#  'منهم': 0.00032084417667819327,
#  'كلمه': 0.00032084417667819327,
#  'منين': 0.00032084417667819327,
#  'شنسوي': 0.00032084417667819327,
#  'اصير': 0.00032084417667819327,
#  'البلد': 0.00032084417667819327,
#  'ورا': 0.00032084417667819327,
#  'علمود': 0.00032084417667819327,
#  'دوله': 0.00032084417667819327,
#  'حب': 0.00032084417667819327,
#  'اقصد': 0.00032084417667819327,
#  'موضوع': 0.00032084417667819327,
#  'الشي': 0.00032084417667819327,
#  'بلوك': 0.00032084417667819327,
#  'كبير': 0.00032084417667819327,
#  'يريد': 0.00032084417667819327,
#  'اكبر': 0.00032084417667819327,
#  'عيد': 0.00032084417667819327,
#  'صباح': 0.00032084417667819327,
#  'امك': 0.00032084417667819327,
#  'راس': 0.00032084417667819327,
#  'يابه': 0.00032084417667819327,
#  'حظ': 0.00032084417667819327,
#  'بلد': 0.00030301950019607143,
#  'داءما': 0.00030301950019607143,
#  'يحب': 0.00030301950019607143,
#  'وهسه': 0.00030301950019607143,
#  'اخي': 0.00030301950019607143,
#  'شوي': 0.00030301950019607143,
#  'فقط': 0.00030301950019607143,
#  'الاسف': 0.00030301950019607143,
#  'اتمني': 0.00030301950019607143,
#  'واضح': 0.00030301950019607143,
#  'اجي': 0.00030301950019607143,
#  'زينه': 0.00030301950019607143,
#  'بنات': 0.00030301950019607143,
#  'لما': 0.00030301950019607143,
#  'نفسي': 0.00030301950019607143,
#  'اسم': 0.00030301950019607143,
#  'كاعد': 0.00030301950019607143,
#  'ماله': 0.00030301950019607143,
#  'الصدر': 0.00030301950019607143,
#  'عفيه': 0.00030301950019607143,
#  'بابا': 0.00030301950019607143,
#  'اوكي': 0.00030301950019607143,
#  'ومنو': 0.0002851948237139496,
#  'وعلي': 0.0002851948237139496,
#  'امين': 0.0002851948237139496,
#  'يوميه': 0.0002851948237139496,
#  'امريكا': 0.0002851948237139496,
#  'علينه': 0.0002851948237139496,
#  'بحياتي': 0.0002851948237139496,
#  'لعراق': 0.0002851948237139496,
#  'شهر': 0.0002851948237139496,
#  'طول': 0.0002851948237139496,
#  'يقول': 0.0002851948237139496,
#  'بتويتر': 0.0002851948237139496,
#  'عمري': 0.0002851948237139496,
#  'اسوي': 0.0002851948237139496,
#  'نشوف': 0.0002851948237139496,
#  'عليج': 0.0002851948237139496,
#  'بالي': 0.0002851948237139496,
#  'حساب': 0.0002851948237139496,
#  'مرحله': 0.0002851948237139496,
#  'ثاني': 0.0002851948237139496,
#  'تشوف': 0.0002851948237139496,
#  'وصلت': 0.0002851948237139496,
#  'البيت': 0.0002851948237139496,
#  'الولد': 0.0002851948237139496,
#  'اشلون': 0.0002851948237139496,
#  'بيا': 0.0002851948237139496,
#  'فعلا': 0.0002851948237139496,
#  'عاشت': 0.0002851948237139496,
#  'اخ': 0.00026737014723182776,
#  'خلص': 0.00026737014723182776,
#  'يسعد': 0.00026737014723182776,
#  'وره': 0.00026737014723182776,
#  'واحنه': 0.00026737014723182776,
#  'بالف': 0.00026737014723182776,
#  'يبقي': 0.00026737014723182776,
#  'اخاف': 0.00026737014723182776,
#  'انسان': 0.00026737014723182776,
#  'كيف': 0.00026737014723182776,
#  'عند': 0.00026737014723182776,
#  'مات': 0.00026737014723182776,
#  'عندنا': 0.00026737014723182776,
#  'اشو': 0.00026737014723182776,
#  'زمان': 0.00026737014723182776,
#  'موت': 0.00026737014723182776,
#  'اكل': 0.00026737014723182776,
#  'بعض': 0.00026737014723182776,
#  'وياهم': 0.00026737014723182776,
#  'ذاك': 0.00026737014723182776,
#  'بيج': 0.00026737014723182776,
#  'اشوفه': 0.00026737014723182776,
#  'اسمي': 0.00026737014723182776,
#  'يومين': 0.00026737014723182776,
#  'ايدك': 0.00026737014723182776,
#  'نص': 0.00026737014723182776,
#  'عمر': 0.00026737014723182776,
#  'روح': 0.00026737014723182776,
#  'عيب': 0.00026737014723182776,
#  'ثانيه': 0.00026737014723182776,
#  'شغل': 0.00026737014723182776,
#  'خرب': 0.00026737014723182776,
#  'ياخي': 0.00024954547074970587,
#  'رجل': 0.00024954547074970587,
#  'بنت': 0.00024954547074970587,
#  'انك': 0.00024954547074970587,
#  'مبروك': 0.00024954547074970587,
#  'الصوره': 0.00024954547074970587,
#  'مبارك': 0.00024954547074970587,
#  'حبيبتي': 0.00024954547074970587,
#  'مصيبه': 0.00024954547074970587,
#  'المالكي': 0.00024954547074970587,
#  'شلونك': 0.00024954547074970587,
#  'عمل': 0.00024954547074970587,
#  'قال': 0.00024954547074970587,
#  'العلم': 0.00024954547074970587,
#  'عبد': 0.00024954547074970587,
#  'اغلب': 0.00024954547074970587,
#  'اما': 0.00024954547074970587,
#  'الحب': 0.00024954547074970587,
#  'اوفر': 0.00024954547074970587,
#  'وليش': 0.00024954547074970587,
#  'يمي': 0.00024954547074970587,
#  'بالبيت': 0.00024954547074970587,
#  'حرام': 0.00024954547074970587,
#  'عيوني': 0.00024954547074970587,
#  'تروح': 0.00024954547074970587,
#  'سب': 0.00024954547074970587,
#  'بينا': 0.00024954547074970587,
#  'فوك': 0.00024954547074970587,
#  'بسب': 0.00024954547074970587,
#  'اخوي': 0.00024954547074970587,
#  'يمعوده': 0.00024954547074970587,
#  'كال': 0.00024954547074970587,
#  'لابو': 0.00024954547074970587,
#  'تدري': 0.00024954547074970587,
#  'اهلا': 0.00024954547074970587,
#  'ذوله': 0.00024954547074970587,
#  'ورده': 0.00024954547074970587,
#  'ماعندي': 0.00023172079426758403,
#  'شيء': 0.00023172079426758403,
#  'اتفق': 0.00023172079426758403,
#  'حسين': 0.00023172079426758403,
#  'كلامي': 0.00023172079426758403,
#  'حاله': 0.00023172079426758403,
#  'عمرك': 0.00023172079426758403,
#  'يمعود': 0.00023172079426758403,
#  'اطلع': 0.00023172079426758403,
#  'حر': 0.00023172079426758403,
#  'الحكومه': 0.00023172079426758403,
#  'دوم': 0.00023172079426758403,
#  'كلمن': 0.00023172079426758403,
#  'چا': 0.00023172079426758403,
#  'چان': 0.00023172079426758403,
#  'ضد': 0.00023172079426758403,
#  'نفسهم': 0.00023172079426758403,
#  'يجوز': 0.00023172079426758403,
#  'راحت': 0.00023172079426758403,
#  'وكت': 0.00023172079426758403,
#  'كميه': 0.00023172079426758403,
#  'راي': 0.00023172079426758403,
#  'مجرد': 0.00023172079426758403,
#  'الحياه': 0.00023172079426758403,
#  'ايه': 0.00023172079426758403,
#  'وبس': 0.00023172079426758403,
#  'اسمع': 0.00023172079426758403,
#  'تسوي': 0.00023172079426758403,
#  'تسلم': 0.00023172079426758403,
#  'داعي': 0.00023172079426758403,
#  'يحفظك': 0.00023172079426758403,
#  'صراحه': 0.00023172079426758403,
#  'المراه': 0.00023172079426758403,
#  'تريد': 0.00023172079426758403,
#  'الهم': 0.00023172079426758403,
#  'حل': 0.00023172079426758403,
#  'خله': 0.00023172079426758403,
#  'يسوي': 0.00023172079426758403,
#  'عمو': 0.00023172079426758403,
#  'هله': 0.00023172079426758403,
#  'المناكحه': 0.00023172079426758403,
#  'فيك': 0.00023172079426758403,
#  'منون': 0.00023172079426758403,
#  'م': 0.00023172079426758403,
#  'رحمه': 0.0002138961177854622,
#  'الموضوع': 0.0002138961177854622,
#  'منها': 0.0002138961177854622,
#  'السوالف': 0.0002138961177854622,
#  'ايدي': 0.0002138961177854622,
#  'صعبه': 0.0002138961177854622,
#  'حكومه': 0.0002138961177854622,
#  'عايش': 0.0002138961177854622,
#  'اتوقع': 0.0002138961177854622,
#  'بقت': 0.0002138961177854622,
#  'عايشين': 0.0002138961177854622,
#  'اشوفك': 0.0002138961177854622,
#  'شسوي': 0.0002138961177854622,
#  'شايف': 0.0002138961177854622,
#  'شفته': 0.0002138961177854622,
#  'الوضع': 0.0002138961177854622,
#  'غيره': 0.0002138961177854622,
#  'بدال': 0.0002138961177854622,
#  'مسوي': 0.0002138961177854622,
#  'وراها': 0.0002138961177854622,
#  'لمن': 0.0002138961177854622,
#  'وياج': 0.0002138961177854622,
#  'اختك': 0.0002138961177854622,
#  'عدها': 0.0002138961177854622,
#  'الجو': 0.0002138961177854622,
#  'نسوي': 0.0002138961177854622,
#  'كلنا': 0.0002138961177854622,
#  'حبيت': 0.0002138961177854622,
#  'حسابك': 0.0002138961177854622,
#  'كثر': 0.0002138961177854622,
#  'اقل': 0.0002138961177854622,
#  'بالشارع': 0.0002138961177854622,
#  'اسراءيل': 0.0002138961177854622,
#  'ديالي': 0.0002138961177854622,
#  'رجال': 0.0002138961177854622,
#  'عاد': 0.0002138961177854622,
#  'اتذكر': 0.0002138961177854622,
#  'عنه': 0.0002138961177854622,
#  'اخذ': 0.0002138961177854622,
#  'كون': 0.0002138961177854622,
#  'الدوله': 0.0002138961177854622,
#  'روحه': 0.0002138961177854622,
#  'ي': 0.0002138961177854622,
#  'ويانه': 0.0002138961177854622,
#  'جهاد': 0.0002138961177854622,
#  'البشر': 0.00019607144130334033,
#  'صرت': 0.00019607144130334033,
#  'العيد': 0.00019607144130334033,
#  'حق': 0.00019607144130334033,
#  'الاخ': 0.00019607144130334033,
#  'طلعوا': 0.00019607144130334033,
#  'سويت': 0.00019607144130334033,
#  'رءيس': 0.00019607144130334033,
#  'جديد': 0.00019607144130334033,
#  'مثلك': 0.00019607144130334033,
#  'كانت': 0.00019607144130334033,
#  'افكر': 0.00019607144130334033,
#  'الجمعه': 0.00019607144130334033,
#  'جديده': 0.00019607144130334033,
#  'الوكت': 0.00019607144130334033,
#  'عنها': 0.00019607144130334033,
#  'يرحمه': 0.00019607144130334033,
#  'رمضان': 0.00019607144130334033,
#  'الورد': 0.00019607144130334033,
#  'ارجع': 0.00019607144130334033,
#  'اسبوع': 0.00019607144130334033,
#  'الايام': 0.00019607144130334033,
#  'يحجون': 0.00019607144130334033,
#  'احبه': 0.00019607144130334033,
#  'جاد': 0.00019607144130334033,
#  'باي': 0.00019607144130334033,
#  'مهم': 0.00019607144130334033,
#  'وهي': 0.00019607144130334033,
#  'صوره': 0.00019607144130334033,
#  'ضحك': 0.00019607144130334033,
#  'الوقت': 0.00019607144130334033,
#  'عليا': 0.00019607144130334033,
#  'وراه': 0.00019607144130334033,
#  'كره': 0.00019607144130334033,
#  'قليل': 0.00019607144130334033,
#  'هناك': 0.00019607144130334033,
#  'الشغله': 0.00019607144130334033,
#  'شغله': 0.00019607144130334033,
#  'لكل': 0.00019607144130334033,
#  'طلاب': 0.00019607144130334033,
#  'تحس': 0.00019607144130334033,
#  'بنفس': 0.00019607144130334033,
#  'رغم': 0.00019607144130334033,
#  'تغريده': 0.00019607144130334033,
#  'اجمل': 0.00019607144130334033,
#  'افضل': 0.00019607144130334033,
#  'وراح': 0.00019607144130334033,
#  'حال': 0.00019607144130334033,
#  'امام': 0.00019607144130334033,
#  'وحتي': 0.00019607144130334033,
#  'السيد': 0.00019607144130334033,
#  'يكلك': 0.00019607144130334033,
#  'بصراحه': 0.00019607144130334033,
#  'زيد': 0.00019607144130334033,
#  'تحياتي': 0.00019607144130334033,
#  'العافيه': 0.00019607144130334033,
#  'اموت': 0.00019607144130334033,
#  'ابويه': 0.00019607144130334033,
#  'ضروري': 0.00019607144130334033,
#  'شكلي': 0.00019607144130334033,
#  'بنيه': 0.00019607144130334033,
#  'تسلميلي': 0.00019607144130334033,
#  'ضلعي': 0.00019607144130334033,
#  'ردت': 0.0001782467648212185,
#  'معك': 0.0001782467648212185,
#  'سيد': 0.0001782467648212185,
#  'ياله': 0.0001782467648212185,
#  'نعمه': 0.0001782467648212185,
#  'تضحك': 0.0001782467648212185,
#  'قلت': 0.0001782467648212185,
#  'وانتم': 0.0001782467648212185,
#  'طبيعي': 0.0001782467648212185,
#  'خاف': 0.0001782467648212185,
#  'نفسيه': 0.0001782467648212185,
#  'هلو': 0.0001782467648212185,
#  'وينه': 0.0001782467648212185,
#  'ساعات': 0.0001782467648212185,
#  'الواحد': 0.0001782467648212185,
#  'مليون': 0.0001782467648212185,
#  'ومو': 0.0001782467648212185,
#  'ابدا': 0.0001782467648212185,
#  'البصره': 0.0001782467648212185,
#  'قويه': 0.0001782467648212185,
#  'اعرفه': 0.0001782467648212185,
#  'القلب': 0.0001782467648212185,
#  'بالنسبه': 0.0001782467648212185,
#  'روحك': 0.0001782467648212185,
#  'جميل': 0.0001782467648212185,
#  'طاءفي': 0.0001782467648212185,
#  'هوايا': 0.0001782467648212185,
#  'سمعت': 0.0001782467648212185,
#  'صارلي': 0.0001782467648212185,
#  'تقريبا': 0.0001782467648212185,
#  'عل': 0.0001782467648212185,
#  'بالك': 0.0001782467648212185,
#  'تغير': 0.0001782467648212185,
#  'الجنه': 0.0001782467648212185,
#  'يمنا': 0.0001782467648212185,
#  'ميعرف': 0.0001782467648212185,
#  'البنيه': 0.0001782467648212185,
#  'ولازم': 0.0001782467648212185,
#  'يردون': 0.0001782467648212185,
#  'لكم': 0.0001782467648212185,
#  'ورد': 0.0001782467648212185,
#  'نحجي': 0.0001782467648212185,
#  'فيها': 0.0001782467648212185,
#  'فكر': 0.0001782467648212185,
#  'الحر': 0.0001782467648212185,
#  'عبالي': 0.0001782467648212185,
#  'حظه': 0.0001782467648212185,
#  'نايم': 0.0001782467648212185,
#  'اقوي': 0.0001782467648212185,
#  'عربيه': 0.0001782467648212185,
#  'فرق': 0.0001782467648212185,
#  'الكهرباء': 0.0001782467648212185,
#  'خاص': 0.0001782467648212185,
#  'مالي': 0.0001782467648212185,
#  'الغلط': 0.0001782467648212185,
#  'ليل': 0.0001782467648212185,
#  'بعيد': 0.0001782467648212185,
#  'شر': 0.0001782467648212185,
#  'لغه': 0.0001782467648212185,
#  'رحت': 0.0001782467648212185,
#  'عراقيه': 0.0001782467648212185,
#  'هيچ': 0.0001782467648212185,
#  'النفس': 0.0001782467648212185,
#  'يله': 0.0001782467648212185,
#  'اخويه': 0.0001782467648212185,
#  'رجعت': 0.0001782467648212185,
#  'كومه': 0.0001782467648212185,
#  'زينب': 0.0001782467648212185,
#  'اضحك': 0.0001782467648212185,
#  'احبك': 0.0001782467648212185,
#  'الذوق': 0.0001782467648212185,
#  'عنك': 0.00016042208833909663,
#  'اخوه': 0.00016042208833909663,
#  'بشر': 0.00016042208833909663,
#  'لها': 0.00016042208833909663,
#  'فيه': 0.00016042208833909663,
#  'ياخذ': 0.00016042208833909663,
#  'الصور': 0.00016042208833909663,
#  'اطفال': 0.00016042208833909663,
#  'تكلم': 0.00016042208833909663,
#  'منونه': 0.00016042208833909663,
#  'الرجال': 0.00016042208833909663,
#  'ينعاد': 0.00016042208833909663,
#  'البال': 0.00016042208833909663,
#  'وربي': 0.00016042208833909663,
#  'بينه': 0.00016042208833909663,
#  'الشيعه': 0.00016042208833909663,
#  'العربيه': 0.00016042208833909663,
#  'ابوك': 0.00016042208833909663,
#  'بسرعه': 0.00016042208833909663,
#  'خبر': 0.00016042208833909663,
#  'الثانيه': 0.00016042208833909663,
#  'علم': 0.00016042208833909663,
#  'الخبر': 0.00016042208833909663,
#  'انوب': 0.00016042208833909663,
#  'رايحه': 0.00016042208833909663,
#  'الزواج': 0.00016042208833909663,
#  'البعض': 0.00016042208833909663,
#  'يحتاج': 0.00016042208833909663,
#  'واكو': 0.00016042208833909663,
#  'تعبانه': 0.00016042208833909663,
#  'النور': 0.00016042208833909663,
#  'معقوله': 0.00016042208833909663,
#  'طاح': 0.00016042208833909663,
#  'ادور': 0.00016042208833909663,
#  'دكتوره': 0.00016042208833909663,
#  'شكل': 0.00016042208833909663,
#  'عمره': 0.00016042208833909663,
#  'عربي': 0.00016042208833909663,
#  'طويله': 0.00016042208833909663,
#  'حسيت': 0.00016042208833909663,
#  'لانه': 0.00016042208833909663,
#  'باسم': 0.00016042208833909663,
#  'طالب': 0.00016042208833909663,
#  'خطا': 0.00016042208833909663,
#  'السب': 0.00016042208833909663,
#  'عني': 0.00016042208833909663,
#  'رد': 0.00016042208833909663,
#  'منشن': 0.00016042208833909663,
#  'حزب': 0.00016042208833909663,
#  'بحياتك': 0.00016042208833909663,
#  'طالعه': 0.00016042208833909663,
#  'طفل': 0.00016042208833909663,
#  'باليل': 0.00016042208833909663,
#  'خصوصا': 0.00016042208833909663,
#  'الغالي': 0.00016042208833909663,
#  'خلك': 0.00016042208833909663,
#  'انام': 0.00016042208833909663,
#  'وشنو': 0.00016042208833909663,
#  'الانستا': 0.00016042208833909663,
#  'مي': 0.00016042208833909663,
#  'ايده': 0.00016042208833909663,
#  'الانبار': 0.00016042208833909663,
#  'شايفه': 0.00016042208833909663,
#  'شباب': 0.00016042208833909663,
#  'كلب': 0.00016042208833909663,
#  'دوام': 0.00016042208833909663,
#  'عطله': 0.00016042208833909663,
#  'اقول': 0.00016042208833909663,
#  'البنت': 0.00016042208833909663,
#  'تخيل': 0.00016042208833909663,
#  'بلا': 0.00016042208833909663,
#  'ساره': 0.00016042208833909663,
#  'نسيت': 0.00016042208833909663,
#  'امتحان': 0.00016042208833909663,
#  'كلكم': 0.00016042208833909663,
#  'برنامج': 0.00016042208833909663,
#  'اكله': 0.00016042208833909663,
#  'كاظم': 0.00016042208833909663,
#  'عندج': 0.00016042208833909663,
#  'الحشد': 0.00016042208833909663,
#  'الكبير': 0.00016042208833909663,
#  'احمد': 0.00016042208833909663,
#  'عيون': 0.00016042208833909663,
#  'بلكي': 0.00016042208833909663,
#  'مسويه': 0.00016042208833909663,
#  'كيوت': 0.00016042208833909663,
#  'ذوقج': 0.00016042208833909663,
#  'اهلي': 0.00016042208833909663,
#  'مالتي': 0.00016042208833909663,
#  'وش': 0.00016042208833909663,
#  'الج': 0.00016042208833909663,
#  'هالمره': 0.00016042208833909663,
#  'مشاكل': 0.0001425974118569748,
#  'معه': 0.0001425974118569748,
#  'اولا': 0.0001425974118569748,
#  'وحدي': 0.0001425974118569748,
#  'يرجع': 0.0001425974118569748,
#  'منا': 0.0001425974118569748,
#  'بالبصره': 0.0001425974118569748,
#  'الظاهر': 0.0001425974118569748,
#  'شخصيه': 0.0001425974118569748,
#  'غريب': 0.0001425974118569748,
#  'بهاي': 0.0001425974118569748,
#  'بقي': 0.0001425974118569748,
#  'لهذا': 0.0001425974118569748,
#  'ومحد': 0.0001425974118569748,
#  'مقصوده': 0.0001425974118569748,
#  'وربك': 0.0001425974118569748,
#  'النسوان': 0.0001425974118569748,
#  'هذوله': 0.0001425974118569748,
#  'بغير': 0.0001425974118569748,
#  'لايك': 0.0001425974118569748,
#  'بعده': 0.0001425974118569748,
#  'الثاني': 0.0001425974118569748,
#  'مساء': 0.0001425974118569748,
#  'بعيده': 0.0001425974118569748,
#  'الرجل': 0.0001425974118569748,
#  'انطيك': 0.0001425974118569748,
#  'يديم': 0.0001425974118569748,
#  'شفتها': 0.0001425974118569748,
#  'العيون': 0.0001425974118569748,
#  'دخل': 0.0001425974118569748,
#  'فكره': 0.0001425974118569748,
#  'الامور': 0.0001425974118569748,
#  'لدرجه': 0.0001425974118569748,
#  'سوالف': 0.0001425974118569748,
#  'عجيب': 0.0001425974118569748,
#  'حكومتنا': 0.0001425974118569748,
#  'باقي': 0.0001425974118569748,
#  'امه': 0.0001425974118569748,
#  'همزين': 0.0001425974118569748,
#  'ويصير': 0.0001425974118569748,
#  'ياريت': 0.0001425974118569748,
#  'صفحه': 0.0001425974118569748,
#  'وجه': 0.0001425974118569748,
#  'استغفر': 0.0001425974118569748,
#  'عادل': 0.0001425974118569748,
#  'شكلك': 0.0001425974118569748,
#  'توصل': 0.0001425974118569748,
#  'خويه': 0.0001425974118569748,
#  'تويت': 0.0001425974118569748,
#  'اسال': 0.0001425974118569748,
#  'خارج': 0.0001425974118569748,
#  'صديقه': 0.0001425974118569748,
#  'بوجه': 0.0001425974118569748,
#  'صديقتي': 0.0001425974118569748,
#  'رجع': 0.0001425974118569748,
#  'ونص': 0.0001425974118569748,
#  'قمه': 0.0001425974118569748,
#  'يسون': 0.0001425974118569748,
#  'اوي': 0.0001425974118569748,
#  'العام': 0.0001425974118569748,
#  'ارد': 0.0001425974118569748,
#  'الها': 0.0001425974118569748,
#  'خاصه': 0.0001425974118569748,
#  'قريب': 0.0001425974118569748,
#  'جذب': 0.0001425974118569748,
#  'يشتغل': 0.0001425974118569748,
#  'وانتو': 0.0001425974118569748,
#  'حسب': 0.0001425974118569748,
#  'عبر': 0.0001425974118569748,
#  'بالضبط': 0.0001425974118569748,
#  'لذلك': 0.0001425974118569748,
#  'كامل': 0.0001425974118569748,
#  'شبيك': 0.0001425974118569748,
#  'احترام': 0.0001425974118569748,
#  'النت': 0.0001425974118569748,
#  'شعور': 0.0001425974118569748,
#  'بيت': 0.0001425974118569748,
#  'شعر': 0.0001425974118569748,
#  'غيرك': 0.0001425974118569748,
#  'حاليا': 0.0001425974118569748,
#  'نكول': 0.0001425974118569748,
#  'كريم': 0.0001425974118569748,
#  'تعب': 0.0001425974118569748,
#  'فرح': 0.0001425974118569748,
#  'منكم': 0.0001425974118569748,
#  'رساله': 0.0001425974118569748,
#  'اغاني': 0.0001425974118569748,
#  'خليها': 0.0001425974118569748,
#  'حشاك': 0.0001425974118569748,
#  'مالها': 0.0001425974118569748,
#  'تاكل': 0.0001425974118569748,
#  'اشياء': 0.0001425974118569748,
#  'تجيب': 0.0001425974118569748,
#  'قوي': 0.0001425974118569748,
#  'الفيس': 0.0001425974118569748,
#  'واعرف': 0.0001425974118569748,
#  'تستاهل': 0.0001425974118569748,
#  'منوع': 0.0001425974118569748,
#  'راتب': 0.0001425974118569748,
#  'المجتمع': 0.0001425974118569748,
#  'ريال': 0.0001425974118569748,
#  'براسي': 0.0001425974118569748,
#  'ميصير': 0.0001425974118569748,
#  'خو': 0.0001425974118569748,
#  'الاول': 0.0001425974118569748,
#  'الحجي': 0.0001425974118569748,
#  'وضع': 0.0001425974118569748,
#  'مناسبه': 0.0001425974118569748,
#  'المثل': 0.0001425974118569748,
#  'بال': 0.0001425974118569748,
#  'حسابي': 0.0001425974118569748,
#  'اخلي': 0.0001425974118569748,
#  'مقتدي': 0.0001425974118569748,
#  'سوه': 0.0001425974118569748,
#  'ضايجه': 0.0001425974118569748,
#  'الناصريه': 0.0001425974118569748,
#  'مليان': 0.0001425974118569748,
#  'جا': 0.0001425974118569748,
#  'يكلي': 0.0001425974118569748,
#  'رب': 0.0001425974118569748,
#  'فايده': 0.0001425974118569748,
#  'اصدقاءي': 0.0001425974118569748,
#  'اغنيه': 0.0001425974118569748,
#  'وهمه': 0.0001425974118569748,
#  'حياتي': 0.0001425974118569748,
#  'يزيد': 0.0001425974118569748,
#  'شعري': 0.0001425974118569748,
#  'عدنا': 0.0001425974118569748,
#  'قلب': 0.0001425974118569748,
#  'يرضي': 0.00012477273537485293,
#  'خلصت': 0.00012477273537485293,
#  'كلك': 0.00012477273537485293,
#  'ماخذ': 0.00012477273537485293,
#  'عباله': 0.00012477273537485293,
#  'ريحه': 0.00012477273537485293,
#  'سبحان': 0.00012477273537485293,
#  'يخاف': 0.00012477273537485293,
#  'الغاليه': 0.00012477273537485293,
#  'صاحب': 0.00012477273537485293,
#  'شبيه': 0.00012477273537485293,
#  'بالعافيه': 0.00012477273537485293,
#  'صحه': 0.00012477273537485293,
#  'قسم': 0.00012477273537485293,
#  'تحت': 0.00012477273537485293,
#  'تبين': 0.00012477273537485293,
#  'نوري': 0.00012477273537485293,
#  'لسانك': 0.00012477273537485293,
#  'التغير': 0.00012477273537485293,
#  'الشرف': 0.00012477273537485293,
#  'ضحكتني': 0.00012477273537485293,
#  'راسي': 0.00012477273537485293,
#  'يجون': 0.00012477273537485293,
#  'يشوفون': 0.00012477273537485293,
#  'لابس': 0.00012477273537485293,
#  'فوق': 0.00012477273537485293,
#  'راسك': 0.00012477273537485293,
#  'المهدي': 0.00012477273537485293,
#  'كفو': 0.00012477273537485293,
#  'قديمه': 0.00012477273537485293,
#  'فلان': 0.00012477273537485293,
#  'صعب': 0.00012477273537485293,
#  'چاي': 0.00012477273537485293,
#  'صارله': 0.00012477273537485293,
#  'اسود': 0.00012477273537485293,
#  'صاحبه': 0.00012477273537485293,
#  'احترامي': 0.00012477273537485293,
#  'يخليك': 0.00012477273537485293,
#  'جو': 0.00012477273537485293,
#  'كبيره': 0.00012477273537485293,
#  'وزير': 0.00012477273537485293,
#  'خليه': 0.00012477273537485293,
#  'شيخ': 0.00012477273537485293,
#  'بهل': 0.00012477273537485293,
#  'قرار': 0.00012477273537485293,
#  'شاءاله': 0.00012477273537485293,
#  'قريت': 0.00012477273537485293,
#  'صديق': 0.00012477273537485293,
#  'مسلسل': 0.00012477273537485293,
#  'بنص': 0.00012477273537485293,
#  'الشباب': 0.00012477273537485293,
#  'بطل': 0.00012477273537485293,
#  'مثال': 0.00012477273537485293,
#  'دخلت': 0.00012477273537485293,
#  'بعدني': 0.00012477273537485293,
#  'مت': 0.00012477273537485293,
#  'تشوفه': 0.00012477273537485293,
#  'متاكده': 0.00012477273537485293,
#  'بالفعل': 0.00012477273537485293,
#  'الامريكان': 0.00012477273537485293,
#  'يطلعون': 0.00012477273537485293,
#  'جايه': 0.00012477273537485293,
#  'بشي': 0.00012477273537485293,
#  'كدام': 0.00012477273537485293,
#  'كد': 0.00012477273537485293,
#  'بهذا': 0.00012477273537485293,
#  'اوف': 0.00012477273537485293,
#  'برا': 0.00012477273537485293,
#  'طريقه': 0.00012477273537485293,
#  'اب': 0.00012477273537485293,
#  'شغلات': 0.00012477273537485293,
#  'جوه': 0.00012477273537485293,
#  'اخذت': 0.00012477273537485293,
#  'وياكم': 0.00012477273537485293,
#  'يجيبون': 0.00012477273537485293,
#  'ابقي': 0.00012477273537485293,
#  'سو': 0.00012477273537485293,
#  'منج': 0.00012477273537485293,
#  'تاخذ': 0.00012477273537485293,
#  'الاكل': 0.00012477273537485293,
#  'نفسك': 0.00012477273537485293,
#  'سياسه': 0.00012477273537485293,
#  'ثلاث': 0.00012477273537485293,
#  'تعبان': 0.00012477273537485293,
#  'صور': 0.00012477273537485293,
#  'عندها': 0.00012477273537485293,
#  'نسوان': 0.00012477273537485293,
#  'حجي': 0.00012477273537485293,
#  ...}

# %%
dict(sorted(model_1["bigram_count"].items(), key=lambda item: item[1], reverse=True))
# Out:
# {('شاء', 'اله'): 47,
#  ('ان', 'شاء'): 41,
#  ('اي', 'واله'): 38,
#  ('بس', 'مو'): 26,
#  ('ه', 'ه'): 26,
#  ('اهم', 'شي'): 24,
#  ('مو', 'بس'): 22,
#  ('بس', 'اني'): 22,
#  ('اكثر', 'من'): 21,
#  ('ما', 'اعرف'): 21,
#  ('اني', 'هم'): 20,
#  ('الي', 'ما'): 20,
#  ('ما', 'ادري'): 19,
#  ('الناس', 'الي'): 19,
#  ('اكو', 'ناس'): 18,
#  ('مع', 'الاسف'): 17,
#  ('اول', 'مره'): 17,
#  ('اني', 'ما'): 17,
#  ('كل', 'ما'): 16,
#  ('ليش', 'ما'): 16,
#  ('كل', 'شي'): 14,
#  ('هو', 'الي'): 14,
#  ('احلي', 'من'): 14,
#  ('بالف', 'خير'): 13,
#  ('مو', 'اني'): 13,
#  ('هذا', 'الي'): 13,
#  ('لا', 'واله'): 13,
#  ('يعني', 'من'): 13,
#  ('من', 'كل'): 13,
#  ('مثل', 'ما'): 13,
#  ('اذا', 'ما'): 13,
#  ('اله', 'يبارك'): 13,
#  ('لحد', 'الان'): 12,
#  ('ه', 'واله'): 12,
#  ('بس', 'من'): 12,
#  ('ه', 'اي'): 12,
#  ('لا', 'مو'): 12,
#  ('بس', 'هو'): 12,
#  ('من', 'الصبح'): 12,
#  ('بس', 'ما'): 12,
#  ('كل', 'يوم'): 12,
#  ('واحد', 'من'): 12,
#  ('بس', 'انت'): 11,
#  ('من', 'وره'): 11,
#  ('من', 'زمان'): 11,
#  ('اله', 'يرحمه'): 11,
#  ('شنو', 'يعني'): 11,
#  ('لو', 'شنو'): 11,
#  ('اول', 'شي'): 11,
#  ('اي', 'شي'): 11,
#  ('مو', 'هيج'): 11,
#  ('واله', 'ما'): 11,
#  ('ما', 'شفت'): 11,
#  ('مدري', 'ليش'): 11,
#  ('كل', 'عام'): 10,
#  ('شنو', 'هل'): 10,
#  ('مو', 'من'): 10,
#  ('حتي', 'لو'): 10,
#  ('لان', 'هو'): 10,
#  ('ه', 'مو'): 10,
#  ('من', 'كثر'): 10,
#  ('اني', 'مو'): 10,
#  ('واله', 'بس'): 10,
#  ('هسه', 'اني'): 10,
#  ('بعد', 'ما'): 10,
#  ('ليش', 'هيج'): 10,
#  ('ما', 'عندي'): 10,
#  ('ما', 'اكدر'): 10,
#  ('عاشت', 'ايدك'): 10,
#  ('يعني', 'مو'): 9,
#  ('اني', 'من'): 9,
#  ('من', 'غير'): 9,
#  ('مو', 'حلوه'): 9,
#  ('ه', 'لا'): 9,
#  ('مو', 'مال'): 9,
#  ('كل', 'سنه'): 9,
#  ('واله', 'مو'): 9,
#  ('حتي', 'ما'): 9,
#  ('مو', 'مثل'): 9,
#  ('لان', 'ما'): 9,
#  ('من', 'واحد'): 9,
#  ('من', 'العراق'): 9,
#  ('علي', 'هذا'): 8,
#  ('مو', 'حلو'): 8,
#  ('كل', 'الي'): 8,
#  ('منو', 'هذا'): 8,
#  ('اذا', 'انت'): 8,
#  ('علي', 'هاي'): 8,
#  ('علي', 'اساس'): 8,
#  ('بس', 'اذا'): 8,
#  ('كلام', 'حلو'): 8,
#  ('لو', 'ما'): 8,
#  ('كل', 'واحد'): 8,
#  ('هو', 'مو'): 8,
#  ('مو', 'كل'): 8,
#  ('ما', 'احب'): 8,
#  ('هذا', 'الكلام'): 8,
#  ('مو', 'زين'): 8,
#  ('هو', 'اني'): 8,
#  ('جهاد', 'المناكحه'): 8,
#  ('سبحان', 'اله'): 7,
#  ('واله', 'اني'): 7,
#  ('اي', 'بس'): 7,
#  ('اله', 'علي'): 7,
#  ('بس', 'واله'): 7,
#  ('الي', 'راح'): 7,
#  ('وين', 'اكو'): 7,
#  ('شي', 'من'): 7,
#  ('اي', 'صح'): 7,
#  ('من', 'ورا'): 7,
#  ('ه', 'بس'): 7,
#  ('احسن', 'من'): 7,
#  ('هذا', 'الشي'): 7,
#  ('اني', 'هيج'): 7,
#  ('يعني', 'ما'): 7,
#  ('من', 'يصير'): 7,
#  ('حتي', 'اذا'): 7,
#  ('لا', 'بس'): 7,
#  ('ما', 'تعرف'): 7,
#  ('واله', 'من'): 7,
#  ('ما', 'راح'): 7,
#  ('مقتدي', 'الصدر'): 7,
#  ('الي', 'صار'): 7,
#  ('ماله', 'داعي'): 7,
#  ('اوفر', 'اوفر'): 7,
#  ('كره', 'كبير'): 7,
#  ('ماشاء', 'اله'): 7,
#  ('الف', 'هله'): 7,
#  ('يسعد', 'مساك'): 6,
#  ('شنو', 'هاي'): 6,
#  ('اذا', 'اكو'): 6,
#  ('اله', 'بس'): 6,
#  ('انت', 'من'): 6,
#  ('ان', 'شاءاله'): 6,
#  ('مو', 'صحيح'): 6,
#  ('اي', 'اي'): 6,
#  ('اي', 'واحد'): 6,
#  ('لان', 'من'): 6,
#  ('شنو', 'السالفه'): 6,
#  ('هاي', 'شنو'): 6,
#  ('من', 'الي'): 6,
#  ('قبل', 'فتره'): 6,
#  ('يحجي', 'علي'): 6,
#  ('لو', 'لا'): 6,
#  ('وما', 'اعرف'): 6,
#  ('اقسم', 'باله'): 6,
#  ('كثر', 'ما'): 6,
#  ('واله', 'يا'): 6,
#  ('ع', 'اساس'): 6,
#  ('مره', 'وحده'): 6,
#  ('من', 'الناس'): 6,
#  ('انت', 'وين'): 6,
#  ('واله', 'لو'): 6,
#  ('ليل', 'نهار'): 6,
#  ('ما', 'عنده'): 6,
#  ('انت', 'ما'): 6,
#  ('من', 'تشوف'): 6,
#  ('او', 'لا'): 6,
#  ('هاي', 'مو'): 6,
#  ('مره', 'ثانيه'): 6,
#  ('اله', 'لا'): 6,
#  ('كلش', 'حلو'): 6,
#  ('حته', 'لو'): 6,
#  ('من', 'الضحك'): 6,
#  ('ليش', 'من'): 6,
#  ('لا', 'لا'): 6,
#  ('بس', 'لا'): 6,
#  ('اعوذ', 'باله'): 6,
#  ('من', 'اشوف'): 6,
#  ('اول', 'ما'): 6,
#  ('يا', 'اخي'): 6,
#  ('ما', 'هو'): 6,
#  ('صباح', 'الخير'): 6,
#  ('يعني', 'هذا'): 5,
#  ('وين', 'المشكله'): 5,
#  ('وراحه', 'البال'): 5,
#  ('من', 'عواده'): 5,
#  ('وانت', 'بخير'): 5,
#  ('ينعاد', 'عليكم'): 5,
#  ('وانت', 'بالف'): 5,
#  ('العمر', 'كله'): 5,
#  ('احنه', 'العراقين'): 5,
#  ('علي', 'من'): 5,
#  ('اذا', 'هيج'): 5,
#  ('انت', 'بس'): 5,
#  ('اكو', 'واحد'): 5,
#  ('الي', 'اعرفه'): 5,
#  ('عبد', 'المهدي'): 5,
#  ('راح', 'يكون'): 5,
#  ('ه', 'حلوه'): 5,
#  ('استغفر', 'اله'): 5,
#  ('راح', 'يصير'): 5,
#  ('اله', 'يخليك'): 5,
#  ('من', 'هاي'): 5,
#  ('ماعرف', 'ليش'): 5,
#  ('بس', 'هم'): 5,
#  ('واله', 'ماعرف'): 5,
#  ('علي', 'تويتر'): 5,
#  ('ماكو', 'شي'): 5,
#  ('شكرا', 'لك'): 5,
#  ('الي', 'هي'): 5,
#  ('جاد', 'وبيان'): 5,
#  ('اني', 'عندي'): 5,
#  ('يعني', 'هسه'): 5,
#  ('اعرف', 'بس'): 5,
#  ('لان', 'اني'): 5,
#  ('من', 'هيج'): 5,
#  ('من', 'يمي'): 5,
#  ('دير', 'بالك'): 5,
#  ('خل', 'نشوف'): 5,
#  ('علي', 'شي'): 5,
#  ('نفس', 'ما'): 5,
#  ('بكل', 'شي'): 5,
#  ('اعرف', 'شنو'): 5,
#  ('الي', 'هو'): 5,
#  ('يعني', 'اذا'): 5,
#  ('علي', 'حساب'): 5,
#  ('من', 'قبل'): 5,
#  ('طالعه', 'من'): 5,
#  ('الحمد', 'له'): 5,
#  ('انا', 'ما'): 5,
#  ('من', 'باب'): 5,
#  ('لازم', 'ما'): 5,
#  ('بكل', 'مكان'): 5,
#  ('يا', 'ريت'): 5,
#  ('شلون', 'ما'): 5,
#  ('الي', 'عنده'): 5,
#  ('لحد', 'ما'): 5,
#  ('هاي', 'وين'): 5,
#  ('ربي', 'يحفظك'): 5,
#  ('ريال', 'مدريد'): 5,
#  ('صار', 'سنين'): 5,
#  ('اعرف', 'شلون'): 5,
#  ('مثل', 'الي'): 5,
#  ('من', 'هسه'): 5,
#  ('ماله', 'علاقه'): 5,
#  ('اي', 'مو'): 5,
#  ('هم', 'ما'): 5,
#  ('ما', 'اريد'): 5,
#  ('الي', 'من'): 5,
#  ('يعني', 'هو'): 5,
#  ('الفيس', 'بوك'): 5,
#  ('الي', 'جاي'): 5,
#  ('شنو', 'الي'): 5,
#  ('مو', 'هو'): 5,
#  ('كل', 'الناس'): 5,
#  ('الي', 'يحجي'): 5,
#  ('مال', 'واحد'): 5,
#  ('لحد', 'هسه'): 5,
#  ('انو', 'هو'): 5,
#  ('فد', 'شي'): 5,
#  ('اني', 'بس'): 5,
#  ('وحده', 'من'): 5,
#  ('بنفس', 'الوقت'): 5,
#  ('هيج', 'شي'): 5,
#  ('لتصدكون', 'شكل'): 5,
#  ('شكل', 'البنات'): 5,
#  ('البنات', 'بفلاتر'): 5,
#  ('بفلاتر', 'السناب'): 5,
#  ('يبارك', 'فيك'): 5,
#  ('منون', 'اله'): 5,
#  ('حياكم', 'اله'): 5,
#  ('من', 'اهل'): 5,
#  ('البليه', 'مايضحك'): 5,
#  ('اذا', 'كان'): 4,
#  ('من', 'وين'): 4,
#  ('اتفق', 'معك'): 4,
#  ('استاذ', 'نعمه'): 4,
#  ('عيدك', 'مبارك'): 4,
#  ('هم', 'راح'): 4,
#  ('حاله', 'نفسيه'): 4,
#  ('كل', 'هذا'): 4,
#  ('ه', 'هاي'): 4,
#  ('واله', 'العظيم'): 4,
#  ('العراق', 'من'): 4,
#  ('لا', 'هاي'): 4,
#  ('مع', 'العلم'): 4,
#  ('كل', 'شيء'): 4,
#  ('علي', 'شنو'): 4,
#  ('هذا', 'ابو'): 4,
#  ('الوحيده', 'الي'): 4,
#  ('صحيح', 'اني'): 4,
#  ('هاي', 'السوالف'): 4,
#  ('اله', 'يديم'): 4,
#  ('اله', 'عليك'): 4,
#  ('بس', 'شنو'): 4,
#  ('مادري', 'ليش'): 4,
#  ('اكيد', 'انت'): 4,
#  ('صحيح', 'بس'): 4,
#  ('اي', 'احد'): 4,
#  ('يوم', 'من'): 4,
#  ('من', 'الايام'): 4,
#  ('صديق', 'عمره'): 4,
#  ('خل', 'اشوف'): 4,
#  ('الي', 'صارت'): 4,
#  ('موجود', 'بس'): 4,
#  ('بس', 'غير'): 4,
#  ('شي', 'بس'): 4,
#  ('لو', 'مو'): 4,
#  ('ه', 'اعرف'): 4,
#  ('ه', 'اني'): 4,
#  ('الحمدله', 'علي'): 4,
#  ('كل', 'خير'): 4,
#  ('اني', 'متاكده'): 4,
#  ('من', 'بغداد'): 4,
#  ('اذا', 'مو'): 4,
#  ('علي', 'طول'): 4,
#  ('جان', 'يكول'): 4,
#  ('شنو', 'معناها'): 4,
#  ('اله', 'يرحم'): 4,
#  ('هم', 'نفس'): 4,
#  ('يعني', 'واله'): 4,
#  ('بس', 'حتي'): 4,
#  ('من', 'اول'): 4,
#  ('هو', 'هذا'): 4,
#  ('الشعب', 'العراقي'): 4,
#  ('من', 'كان'): 4,
#  ('مثل', 'قبل'): 4,
#  ('كم', 'يوم'): 4,
#  ('الف', 'عافيه'): 4,
#  ('علي', 'ايران'): 4,
#  ('بس', 'انتي'): 4,
#  ('بس', 'شنسوي'): 4,
#  ('اله', 'كريم'): 4,
#  ('من', 'هذه'): 4,
#  ('اذا', 'واحد'): 4,
#  ('هذا', 'اليوم'): 4,
#  ('كم', 'واحد'): 4,
#  ('شنو', 'ما'): 4,
#  ('لان', 'اذا'): 4,
#  ('اذا', 'صار'): 4,
#  ('واحد', 'ع'): 4,
#  ('الي', 'بيها'): 4,
#  ('اكو', 'هيج'): 4,
#  ('هذا', 'مو'): 4,
#  ('ما', 'بيها'): 4,
#  ('انت', 'مو'): 4,
#  ('شي', 'حتي'): 4,
#  ('انا', 'هم'): 4,
#  ('بس', 'لو'): 4,
#  ('اكثر', 'شي'): 4,
#  ('بدون', 'ما'): 4,
#  ('بس', 'هسه'): 4,
#  ('اله', 'ما'): 4,
#  ('حتي', 'لا'): 4,
#  ('واله', 'اذا'): 4,
#  ('لا', 'ما'): 4,
#  ('زين', 'ما'): 4,
#  ('وين', 'جنت'): 4,
#  ('في', 'كل'): 4,
#  ('هاي', 'الي'): 4,
#  ('واحد', 'ما'): 4,
#  ('هاي', 'مال'): 4,
#  ('ما', 'بقي'): 4,
#  ('بقي', 'شي'): 4,
#  ('ما', 'تشوف'): 4,
#  ('من', 'الحر'): 4,
#  ('ما', 'شايف'): 4,
#  ('ناس', 'ما'): 4,
#  ('ما', 'عندها'): 4,
#  ('المشكله', 'مو'): 4,
#  ('راس', 'السنه'): 4,
#  ('بعيد', 'عن'): 4,
#  ('شي', 'حلو'): 4,
#  ('ما', 'عندهم'): 4,
#  ('اني', 'اكثر'): 4,
#  ('يجي', 'يوم'): 4,
#  ('من', 'فتره'): 4,
#  ('شنو', 'هذا'): 4,
#  ('ولا', 'نفس'): 4,
#  ('من', 'ال'): 4,
#  ('بس', 'هذا'): 4,
#  ('صار', 'سنه'): 4,
#  ('هاي', 'الناس'): 4,
#  ('ما', 'عدها'): 4,
#  ('هسه', 'من'): 4,
#  ('من', 'شخص'): 4,
#  ('هادي', 'العامري'): 4,
#  ('منو', 'الي'): 4,
#  ('مو', 'كافي'): 4,
#  ('صباح', 'النور'): 4,
#  ('من', 'ايدي'): 4,
#  ('اريد', 'واحد'): 4,
#  ('مو', 'انت'): 4,
#  ('احنه', 'الي'): 4,
#  ('شي', 'مو'): 4,
#  ('بس', 'دا'): 4,
#  ('من', 'وراه'): 4,
#  ('من', 'البارحه'): 4,
#  ('ما', 'اتذكر'): 4,
#  ('ليش', 'انته'): 4,
#  ('عندي', 'امتحان'): 4,
#  ('اني', 'هسه'): 4,
#  ('اني', 'الي'): 4,
#  ('شكد', 'اكره'): 4,
#  ('ابو', 'يسر'): 4,
#  ('مدري', 'منين'): 4,
#  ('شويه', 'شويه'): 4,
#  ('مو', 'زينه'): 4,
#  ('عندي', 'سءال'): 4,
#  ('هيج', 'من'): 4,
#  ('هاي', 'هم'): 4,
#  ('ذا', 'فويس'): 4,
#  ('والحمد', 'له'): 4,
#  ('اله', 'يسلمك'): 4,
#  ('ما', 'اتحمل'): 4,
#  ('ما', 'اروح'): 4,
#  ('السناب', 'لتصدكون'): 4,
#  ('واصل', 'مرحله'): 4,
#  ('شكد', 'ما'): 4,
#  ('يا', 'جماعه'): 4,
#  ('اكبر', 'من'): 4,
#  ('واله', 'عيب'): 4,
#  ('من', 'قال'): 4,
#  ('علي', 'امك'): 4,
#  ('سناب', 'جات'): 4,
#  ('صاير', 'كلش'): 4,
#  ('كلش', 'ما'): 4,
#  ('ما', 'يعرف'): 4,
#  ('تويتر', 'صاير'): 4,
#  ('هو', 'ما'): 4,
#  ('هاي', 'اني'): 4,
#  ('منو', 'هاي'): 4,
#  ('اروح', 'ماروح'): 4,
#  ('شكو', 'ماكو'): 4,
#  ('من', 'يحجي'): 4,
#  ('حتي', 'من'): 4,
#  ('بقت', 'علي'): 4,
#  ('شهاده', 'اعتز'): 4,
#  ('اعتز', 'بيها'): 4,
#  ('هلا', 'هلا'): 4,
#  ('اله', 'يا'): 4,
#  ('انت', 'بخير'): 4,
#  ('مو', 'احلي'): 4,
#  ('ساعه', 'سوده'): 4,
#  ('بمليون', 'خير'): 4,
#  ('يا', 'طيب'): 4,
#  ('من', 'ذوقج'): 4,
#  ('عام', 'وانت'): 4,
#  ('من', 'اجمل'): 4,
#  ('اله', 'ربي'): 4,
#  ('الف', 'مبروك'): 4,
#  ('مع', 'الناس'): 4,
#  ('صح', 'السانك'): 4,
#  ('عرفت', 'ان'): 4,
#  ('علي', 'باب'): 3,
#  ('اله', 'يرضي'): 3,
#  ('اولا', 'اني'): 3,
#  ('وهذا', 'الي'): 3,
#  ('ابن', 'عمي'): 3,
#  ('بس', 'ابو'): 3,
#  ('قبل', 'كم'): 3,
#  ('من', 'حق'): 3,
#  ('صاحب', 'التغريده'): 3,
#  ('انا', 'قلت'): 3,
#  ('كل', 'شوي'): 3,
#  ('بالعافيه', 'عليك'): 3,
#  ('عليك', 'وعلي'): 3,
#  ('وانتم', 'بالف'): 3,
#  ('وعساكم', 'من'): 3,
#  ('عام', 'وانتم'): 3,
#  ('نوري', 'المالكي'): 3,
#  ('صح', 'لسانك'): 3,
#  ('يسعد', 'صباحك'): 3,
#  ('بس', 'اعتقد'): 3,
#  ('رءيس', 'الوزراء'): 3,
#  ('الي', 'ديصير'): 3,
#  ('مو', 'بعيده'): 3,
#  ('خط', 'احمر'): 3,
#  ('واحد', 'لابس'): 3,
#  ('هذا', 'شنو'): 3,
#  ('من', 'العراقين'): 3,
#  ('اخر', 'واحد'): 3,
#  ('ه', 'ليش'): 3,
#  ('اني', 'علي'): 3,
#  ('علي', 'العراق'): 3,
#  ('بس', 'سءال'): 3,
#  ('مو', 'الي'): 3,
#  ('اني', 'لو'): 3,
#  ('اذا', 'هو'): 3,
#  ('مو', 'احسن'): 3,
#  ('من', 'وكت'): 3,
#  ('بس', 'هواي'): 3,
#  ('حلوه', 'بس'): 3,
#  ('دوم', 'الضحكه'): 3,
#  ('سءال', 'شنو'): 3,
#  ('عليكم', 'بالصحه'): 3,
#  ('عادل', 'عبد'): 3,
#  ('يثخن', 'لبنكم'): 3,
#  ('لكن', 'انا'): 3,
#  ('تره', 'مو'): 3,
#  ('بيه', 'بس'): 3,
#  ('هي', 'هاي'): 3,
#  ('اساس', 'انت'): 3,
#  ('يعني', 'انت'): 3,
#  ('عليه', 'بس'): 3,
#  ('بس', 'انشر'): 3,
#  ('اروح', 'اروح'): 3,
#  ('ولو', 'اني'): 3,
#  ('ورا', 'ما'): 3,
#  ('من', 'قريت'): 3,
#  ('صح', 'مو'): 3,
#  ('من', 'سمعت'): 3,
#  ('سمعت', 'قصي'): 3,
#  ('اني', 'احب'): 3,
#  ('هل', 'شي'): 3,
#  ('شي', 'اني'): 3,
#  ('فتره', 'طويله'): 3,
#  ('قصي', 'خولي'): 3,
#  ('نفس', 'الحاله'): 3,
#  ('يعني', 'انتي'): 3,
#  ('اي', 'اعرف'): 3,
#  ('علي', 'صفحه'): 3,
#  ('بس', 'هنا'): 3,
#  ('بس', 'شو'): 3,
#  ('اعرف', 'مو'): 3,
#  ('في', 'سبيل'): 3,
#  ('اخاف', 'من'): 3,
#  ('اوي', 'اوي'): 3,
#  ('اغلب', 'الاحيان'): 3,
#  ('الي', 'اسمها'): 3,
#  ('لك', 'انت'): 3,
#  ('الك', 'وحشه'): 3,
#  ('ه', 'انت'): 3,
#  ('غير', 'شي'): 3,
#  ('هيج', 'واله'): 3,
#  ('بس', 'يعني'): 3,
#  ('يا', 'اله'): 3,
#  ('مو', 'انتي'): 3,
#  ('اعتقد', 'ان'): 3,
#  ('تري', 'هو'): 3,
#  ('اله', 'يشفي'): 3,
#  ('واحد', 'يشوف'): 3,
#  ('من', 'مات'): 3,
#  ('شي', 'يعني'): 3,
#  ('اله', 'يستر'): 3,
#  ('يستر', 'من'): 3,
#  ('شي', 'ما'): 3,
#  ('ما', 'يعجبني'): 3,
#  ('الي', 'جنت'): 3,
#  ('علي', 'صدام'): 3,
#  ('هذا', 'منو'): 3,
#  ('بس', 'اكيد'): 3,
#  ('بس', 'ه'): 3,
#  ('واله', 'هو'): 3,
#  ('كل', 'قلبي'): 3,
#  ('بس', 'يمكن'): 3,
#  ('شي', 'يصير'): 3,
#  ('من', 'هذا'): 3,
#  ('اله', 'يكثر'): 3,
#  ('هذا', 'مال'): 3,
#  ('لان', 'مو'): 3,
#  ('شي', 'لا'): 3,
#  ('ليش', 'يعني'): 3,
#  ('المفروض', 'يكون'): 3,
#  ('بكل', 'تاكيد'): 3,
#  ('بس', 'انا'): 3,
#  ('انا', 'مو'): 3,
#  ('الي', 'اريد'): 3,
#  ('من', 'جديد'): 3,
#  ('علي', 'كل'): 3,
#  ('من', 'الصغر'): 3,
#  ('بعد', 'هذا'): 3,
#  ('اريد', 'افتهم'): 3,
#  ('وشي', 'ثاني'): 3,
#  ('اذا', 'جنت'): 3,
#  ('انكر', 'هالشي'): 3,
#  ('العراقي', 'من'): 3,
#  ('هواي', 'ما'): 3,
#  ('غير', 'اني'): 3,
#  ('ما', 'احجي'): 3,
#  ('يعني', 'شي'): 3,
#  ('من', 'الانستا'): 3,
#  ('خايف', 'من'): 3,
#  ('بس', 'مال'): 3,
#  ('اكبر', 'مني'): 3,
#  ('لان', 'اكو'): 3,
#  ('لان', 'راح'): 3,
#  ('انتي', 'شنو'): 3,
#  ('صايره', 'ما'): 3,
#  ('ما', 'كلت'): 3,
#  ('ما', 'يردون'): 3,
#  ('ما', 'يحتاج'): 3,
#  ('ما', 'حسيت'): 3,
#  ('بس', 'شوفي'): 3,
#  ('ترا', 'ما'): 3,
#  ('هذا', 'الواقع'): 3,
#  ('يوم', 'الجمعه'): 3,
#  ('يعني', 'لازم'): 3,
#  ('من', 'ناس'): 3,
#  ('بس', 'المشكله'): 3,
#  ('قبل', 'سنه'): 3,
#  ('طبعا', 'اذا'): 3,
#  ('ما', 'تشوفون'): 3,
#  ('مو', 'انا'): 3,
#  ('شفت', 'واحد'): 3,
#  ('شيصير', 'لو'): 3,
#  ('ه', 'من'): 3,
#  ('وانتي', 'بالف'): 3,
#  ('ومن', 'عمري'): 3,
#  ('علي', 'عمرك'): 3,
#  ('لا', 'كل'): 3,
#  ('حيل', 'من'): 3,
#  ('خطيه', 'واله'): 3,
#  ('لا', 'وين'): 3,
#  ('وكل', 'سنه'): 3,
#  ('سنه', 'وانت'): 3,
#  ('منو', 'قنع'): 3,
#  ('ه', 'انا'): 3,
#  ('واله', 'هاي'): 3,
#  ('اجي', 'يمكم'): 3,
#  ('ما', 'يصير'): 3,
#  ('ترا', 'مو'): 3,
#  ('لازم', 'تكون'): 3,
#  ('صباح', 'الورد'): 3,
#  ('عمري', 'ع'): 3,
#  ('واقع', 'حال'): 3,
#  ('مو', 'لو'): 3,
#  ('مو', 'مو'): 3,
#  ('انعل', 'ابوكم'): 3,
#  ('خوش', 'ولد'): 3,
#  ('اصلا', 'احنه'): 3,
#  ('واحد', 'يكول'): 3,
#  ('ما', 'اصوم'): 3,
#  ('مو', 'طبيعي'): 3,
#  ('الي', 'شفتها'): 3,
#  ('بس', 'هاي'): 3,
#  ('ادري', 'بس'): 3,
#  ('مع', 'احترامي'): 3,
#  ('بالعكس', 'انا'): 3,
#  ('يمكن', 'ما'): 3,
#  ('حتي', 'اكدر'): 3,
#  ('بس', 'حبيت'): 3,
#  ('مثل', 'هاي'): 3,
#  ('اشرب', 'مي'): 3,
#  ('هواي', 'بس'): 3,
#  ('هي', 'الي'): 3,
#  ('خليها', 'سكته'): 3,
#  ('انتي', 'من'): 3,
#  ('من', 'المطار'): 3,
#  ('شلون', 'راح'): 3,
#  ('الشعب', 'الي'): 3,
#  ('اي', 'شخص'): 3,
#  ('مره', 'اشوف'): 3,
#  ('ع', 'العموم'): 3,
#  ('اقوي', 'من'): 3,
#  ('بدال', 'ما'): 3,
#  ('ولحد', 'الان'): 3,
#  ('بس', 'هي'): 3,
#  ('بيني', 'وبين'): 3,
#  ('هو', 'هيج'): 3,
#  ('الي', 'خله'): 3,
#  ('الصدر', 'من'): 3,
#  ('اني', 'كنت'): 3,
#  ('لا', 'حس'): 3,
#  ('حس', 'ولا'): 3,
#  ('ما', 'تستحي'): 3,
#  ('واحد', 'يحجي'): 3,
#  ('علي', 'الاقل'): 3,
#  ('علي', 'اعتبار'): 3,
#  ('خو', 'مو'): 3,
#  ('ما', 'عندك'): 3,
#  ('اهلا', 'وسهلا'): 3,
#  ('هاي', 'الوادم'): 3,
#  ('الي', 'يريد'): 3,
#  ('ولد', 'الخايبه'): 3,
#  ('هم', 'ماكو'): 3,
#  ('نفسهم', 'الي'): 3,
#  ('راح', 'يطلع'): 3,
#  ('ما', 'طلع'): 3,
#  ('ذاك', 'الرجال'): 3,
#  ('واحد', 'مو'): 3,
#  ('اله', 'يطيح'): 3,
#  ('علي', 'راس'): 3,
#  ('استغربت', 'من'): 3,
#  ('نفس', 'الشي'): 3,
#  ('من', 'اصلك'): 3,
#  ('اصلك', 'الطيب'): 3,
#  ('اعرفه', 'انو'): 3,
#  ('علي', 'احد'): 3,
#  ('البنات', 'الي'): 3,
#  ('بالصحه', 'وراحه'): 3,
#  ('عادي', 'تصير'): 3,
#  ('احنه', 'مو'): 3,
#  ('شنو', 'معني'): 3,
#  ('بيه', 'لا'): 3,
#  ('انت', 'الي'): 3,
#  ('اياد', 'علاوي'): 3,
#  ('اني', 'كلت'): 3,
#  ('يبارك', 'بيج'): 3,
#  ('ابن', 'عمتي'): 3,
#  ('طلع', 'اكو'): 3,
#  ('كيوت', 'بس'): 3,
#  ('رب', 'العالمين'): 3,
#  ('من', 'احد'): 3,
#  ('اني', 'ليش'): 3,
#  ('ولا', 'مره'): 3,
#  ('عيد', 'ميلادي'): 3,
#  ('هو', 'وينه'): 3,
#  ('شني', 'هاي'): 3,
#  ('بيه', 'خلقه'): 3,
#  ('اخر', 'من'): 3,
#  ('الي', 'يعرف'): 3,
#  ('مو', 'ضروري'): 3,
#  ('اكره', 'الناس'): 3,
#  ('الي', 'تطلع'): 3,
#  ('هسه', 'صارت'): 3,
#  ('ماجد', 'المهندس'): 3,
#  ('اي', 'عفيه'): 3,
#  ('واحد', 'واحد'): 3,
#  ('باجر', 'عندي'): 3,
#  ('من', 'ما'): 3,
#  ('اشبع', 'نوم'): 3,
#  ('علي', 'نعمه'): 3,
#  ('ملعون', 'ابو'): 3,
#  ('اكثر', 'ما'): 3,
#  ('حلو', 'من'): 3,
#  ('من', 'اجي'): 3,
#  ('اله', 'ياخذج'): 3,
#  ('وجهه', 'نظر'): 3,
#  ('هيج', 'بس'): 3,
#  ('بس', 'همه'): 3,
#  ('وضع', 'البلد'): 3,
#  ('البلد', 'مو'): 3,
#  ('صوج', 'الي'): 3,
#  ('الي', 'انتخبو'): 3,
#  ('فد', 'مره'): 3,
#  ('عادي', 'مو'): 3,
#  ('شوف', 'شلون'): 3,
#  ('مره', 'اسمع'): 3,
#  ('بس', 'انتو'): 3,
#  ('اريد', 'احجي'): 3,
#  ('بدون', 'سب'): 3,
#  ('بس', 'اله'): 3,
#  ('انته', 'من'): 3,
#  ('اذا', 'انتو'): 3,
#  ('ما', 'اشوف'): 3,
#  ('انو', 'اني'): 3,
#  ('اني', 'دا'): 3,
#  ('مو', 'الكل'): 3,
#  ('لا', 'اني'): 3,
#  ('انو', 'من'): 3,
#  ('كلامك', 'صحيح'): 3,
#  ('يجي', 'يكلي'): 3,
#  ('يمه', 'فدوه'): 3,
#  ('ليش', 'جذي'): 3,
#  ('العراق', 'واله'): 3,
#  ('تدري', 'اني'): 3,
#  ('كل', 'شويه'): 3,
#  ('هاي', 'لان'): 3,
#  ('من', 'سنه'): 3,
#  ('وحده', 'اسمه'): 3,
#  ('شكلي', 'من'): 3,
#  ('الالعاب', 'الناريه'): 3,
#  ('مو', 'مهم'): 3,
#  ('كله', 'علي'): 3,
#  ('الي', 'عند'): 3,
#  ('شنو', 'راح'): 3,
#  ('كوت', 'تويت'): 3,
#  ('كل', 'مره'): 3,
#  ('هذا', 'لو'): 3,
#  ('الي', 'داءما'): 3,
#  ('مت', 'من'): 3,
#  ('اصلا', 'ما'): 3,
#  ('ال', 'سعود'): 3,
#  ('بجهاد', 'المناكحه'): 3,
#  ('ولد', 'الملحه'): 3,
#  ('هاي', 'من'): 3,
#  ('يبارك', 'بيك'): 3,
#  ('حبيبي', 'انت'): 3,
#  ('خير', 'ما'): 3,
#  ('ومن', 'ثم'): 3,
#  ('ثم', 'تكلم'): 3,
#  ('صدق', 'من'): 3,
#  ('هاي', 'اذا'): 3,
#  ('امك', 'او'): 3,
#  ('اسم', 'واحد'): 3,
#  ('علي', 'هل'): 3,
#  ('واحد', 'حلو'): 3,
#  ('اني', 'صايره'): 3,
#  ('الي', 'علي'): 3,
#  ('احلي', 'شي'): 3,
#  ('يا', 'ربي'): 3,
#  ('اني', 'كلش'): 3,
#  ('اريد', 'اصير'): 3,
#  ('لعبت', 'نفسي'): 3,
#  ('حلو', 'بس'): 3,
#  ('احس', 'اذا'): 3,
#  ('وين', 'رايح'): 3,
#  ('حتي', 'اني'): 3,
#  ('من', 'كلت'): 3,
#  ('هسه', 'ما'): 3,
#  ('منو', 'كلك'): 3,
#  ('ويا', 'واحد'): 3,
#  ('بدل', 'ما'): 3,
#  ('من', 'توصل'): 3,
#  ('وانت', 'ما'): 3,
#  ('ما', 'سويت'): 3,
#  ('ما', 'رح'): 3,
#  ('اكيد', 'ما'): 3,
#  ('احجي', 'ويا'): 3,
#  ('اروح', 'لدوام'): 3,
#  ('ماروح', 'اروح'): 3,
#  ('زياده', 'عن'): 3,
#  ('عن', 'الزوم'): 3,
#  ('اني', 'وين'): 3,
#  ('شكرا', 'من'): 3,
#  ('شنو', 'من'): 3,
#  ('بس', 'احب'): 3,
#  ('جان', 'ما'): 3,
#  ('ما', 'عندنا'): 3,
#  ('قبل', 'ما'): 3,
#  ('واله', 'هيج'): 3,
#  ('اروح', 'لا'): 3,
#  ('الحلوه', 'من'): 3,
#  ('من', 'هواي'): 3,
#  ('ما', 'شاء'): 3,
#  ('العراق', 'بس'): 3,
#  ('بعد', 'الي'): 3,
#  ('هاي', 'ما'): 3,
#  ('ما', 'اعتقد'): 3,
#  ('اي', 'يا'): 3,
#  ('لعد', 'شنو'): 3,
#  ('كل', 'شخص'): 3,
#  ('مو', 'شرط'): 3,
#  ('تطب', 'طب'): 3,
#  ('ما', 'تقصر'): 3,
#  ('كل', 'الهلا'): 3,
#  ('يا', 'ورد'): 3,
#  ('ماكو', 'فرق'): 3,
#  ('بخير', 'اذا'): 3,
#  ('كل', 'الخير'): 3,
#  ('ابو', 'نوره'): 3,
#  ('شلونك', 'انت'): 3,
#  ('تحياتي', 'لك'): 3,
#  ('سوده', 'يوم'): 3,
#  ('وانت', 'بمليون'): 3,
#  ('وان', 'شاء'): 3,
#  ('اتفق', 'بس'): 3,
#  ('يا', 'بعد'): 3,
#  ('راح', 'تكون'): 3,
#  ('صار', 'اسبوع'): 3,
#  ('يا', 'كلب'): 3,
#  ('ما', 'دام'): 3,
#  ('اكيد', 'بس'): 3,
#  ('الي', 'يبيع'): 3,
#  ('شترجي', 'منه'): 3,
#  ('حزب', 'اله'): 3,
#  ('ايران', 'ولا'): 3,
#  ('هله', 'ومرحبا'): 3,
#  ('ايروحلج', 'فدوه'): 3,
#  ('مدري', 'انت'): 3,
#  ('شر', 'البليه'): 3,
#  ('عليك', 'يا'): 3,
#  ('نهار', 'والعن'): 3,
#  ('منو', 'يعرف'): 3,
#  ('والي', 'عنده'): 3,
#  ('ماهو', 'ضروري'): 3,
#  ('واله', 'واحشني'): 3,
#  ('تضحك', 'عليه'): 3,
#  ('هاي', 'الصفات'): 3,
#  ('بيه', 'حظ'): 3,
#  ('حظ', 'لا'): 3,
#  ('قمه', 'الذوق'): 3,
#  ('حيه', 'ذوله'): 3,
#  ('اله', 'يحفظهم'): 3,
#  ('ابو', 'فطم'): 3,
#  ('اله', 'يحفظك'): 3,
#  ('مبين', 'من'): 2,
#  ('يسلملي', 'مرورك'): 2,
#  ('هل', 'الغيبه'): 2,
#  ('يرضي', 'عنك'): 2,
#  ('المفروض', 'حتي'): 2,
#  ('اني', 'ردت'): 2,
#  ('علي', 'رجل'): 2,
#  ('مقوله', 'العراق'): 2,
#  ('واله', 'هذا'): 2,
#  ('معك', 'بس'): 2,
#  ('لا', 'ان'): 2,
#  ('العراق', 'الي'): 2,
#  ('كلبه', 'ورم'): 2,
#  ('ورم', 'من'): 2,
#  ('بكل', 'شيء'): 2,
#  ('ماخذ', 'اي'): 2,
#  ('علي', 'قدر'): 2,
#  ('دمر', 'العراق'): 2,
#  ('خوش', 'من'): 2,
#  ('ابو', 'جاسم'): 2,
#  ('كم', 'سنه'): 2,
#  ('هسه', 'صرت'): 2,
#  ('تكلم', 'عن'): 2,
#  ('الي', 'دمرتوه'): 2,
#  ('عليكم', 'كل'): 2,
#  ('الصوره', 'الي'): 2,
#  ('الظاهر', 'انت'): 2,
#  ('حنان', 'الفتلاوي'): 2,
#  ('حق', 'اي'): 2,
#  ('الامن', 'والامان'): 2,
#  ('استاذ', 'محمد'): 2,
#  ('محمد', 'لو'): 2,
#  ('لو', 'اعرف'): 2,
#  ('انا', 'وانت'): 2,
#  ('هاي', 'بس'): 2,
#  ('بهاي', 'السوالف'): 2,
#  ('السوالف', 'من'): 2,
#  ('لان', 'انت'): 2,
#  ('امين', 'يارب'): 2,
#  ('ينعاد', 'عليك'): 2,
#  ('صحه', 'وسلامه'): 2,
#  ('تحقيق', 'كل'): 2,
#  ('من', 'اخلاقك'): 2,
#  ('اخلاقك', 'الحلوه'): 2,
#  ('وينعاد', 'عليكم'): 2,
#  ('طلعوا', 'كلهم'): 2,
#  ('واله', 'اكو'): 2,
#  ('اله', 'احنه'): 2,
#  ('وعلي', 'هل'): 2,
#  ('هل', 'الرنه'): 2,
#  ('لا', 'ابد'): 2,
#  ('يستاهل', 'بس'): 2,
#  ('هاي', 'النسوان'): 2,
#  ('اله', 'خير'): 2,
#  ('احنه', 'هم'): 2,
#  ('حتي', 'يبقي'): 2,
#  ('ابو', 'العدس'): 2,
#  ('الواحد', 'من'): 2,
#  ('اله', 'بلانه'): 2,
#  ('لك', 'كل'): 2,
#  ('عندي', 'خبر'): 2,
#  ('من', 'زوجته'): 2,
#  ('صح', 'لو'): 2,
#  ('كلشي', 'اتوقع'): 2,
#  ('مثلك', 'اي'): 2,
#  ('اله', 'سبحانه'): 2,
#  ('سبحانه', 'وتعالي'): 2,
#  ('من', 'حكومه'): 2,
#  ('مكن', 'تكون'): 2,
#  ('لكن', 'غير'): 2,
#  ('شو', 'انا'): 2,
#  ('دكتور', 'سليم'): 2,
#  ('بس', 'اطلع'): 2,
#  ('ابدا', 'مو'): 2,
#  ('علي', 'راسي'): 2,
#  ('من', 'بابل'): 2,
#  ('الك', 'اله'): 2,
#  ('اله', 'ياعراق'): 2,
#  ('الي', 'ع'): 2,
#  ('راح', 'انطيك'): 2,
#  ('واحد', 'افندي'): 2,
#  ('افندي', 'واحد'): 2,
#  ('لابس', 'دشداشه'): 2,
#  ('منو', 'جاب'): 2,
#  ('مكن', 'تفسر'): 2,
#  ('هاي', 'النماذج'): 2,
#  ('العراق', 'مع'): 2,
#  ('اني', 'هذا'): 2,
#  ('ربي', 'يحفظه'): 2,
#  ('ربي', 'يديم'): 2,
#  ('بيكم', 'حتي'): 2,
#  ('عندنا', 'بس'): 2,
#  ('صعبه', 'عليه'): 2,
#  ('اذا', 'صح'): 2,
#  ('الوكت', 'كله'): 2,
#  ('الامور', 'الي'): 2,
#  ('اذا', 'عرفت'): 2,
#  ('عرفت', 'ليش'): 2,
#  ('حياك', 'اله'): 2,
#  ('اني', 'شفته'): 2,
#  ('علي', 'ابو'): 2,
#  ('انسجام', 'الغراوي'): 2,
#  ('واله', 'هي'): 2,
#  ('علي', 'يد'): 2,
#  ('هسه', 'صحه'): 2,
#  ('صحه', 'ضميره'): 2,
#  ('يستاهل', 'كل'): 2,
#  ('كل', 'امنياتك'): 2,
#  ('ويجيك', 'واحد'): 2,
#  ('واحد', 'عنده'): 2,
#  ('ابو', 'مازن'): 2,
#  ('واله', 'عمي'): 2,
#  ('بيه', 'اذا'): 2,
#  ('شلون', 'عرفت'): 2,
#  ('الي', 'اجه'): 2,
#  ('مو', 'خوش'): 2,
#  ('واله', 'احنه'): 2,
#  ('احنه', 'شعب'): 2,
#  ('يسعدك', 'ربي'): 2,
#  ('انت', 'عندك'): 2,
#  ('بعد', 'روحي'): 2,
#  ('مات', 'من'): 2,
#  ('مره', 'اشوفك'): 2,
#  ('هواي', 'صارله'): 2,
#  ('صارله', 'لابس'): 2,
#  ('كلشي', 'يصير'): 2,
#  ('بس', 'بالعراق'): 2,
#  ('هسه', 'عرفت'): 2,
#  ('كلام', 'جميل'): 2,
#  ('ياريت', 'لو'): 2,
#  ('صفحه', 'جديده'): 2,
#  ('اكيد', 'كل'): 2,
#  ...}

# %%
model_1["bigrams_prob"]
# Out:
# {('لكن', 'بالنهايه'): 0.022222222222222223,
#  ('بالنهايه', 'ينتفض'): 0.3333333333333333,
#  ('ينتفض', 'يغير'): 1.0,
#  ('يغير', 'يعني'): 0.5,
#  ('يعني', 'هذا'): 0.01953125,
#  ('هذا', 'محسوب'): 0.004048582995951417,
#  ('محسوب', 'علي'): 0.5,
#  ('علي', 'البشر'): 0.002070393374741201,
#  ('البشر', 'حيونه'): 0.09090909090909091,
#  ('حيونه', 'وحشيه'): 0.3333333333333333,
#  ('وحشيه', 'وتطلبون'): 1.0,
#  ('وتطلبون', 'من'): 1.0,
#  ('من', 'الغرب'): 0.0009643201542912247,
#  ('الغرب', 'يحترمكم'): 0.25,
#  ('يحترمكم', 'ويءمن'): 1.0,
#  ('ويءمن', 'بدينكم'): 1.0,
#  ('بدينكم', 'ولاينعتكم'): 1.0,
#  ('ولاينعتكم', 'بالارهاب'): 1.0,
#  ('بالارهاب', 'مبين'): 1.0,
#  ('مبين', 'من'): 0.4,
#  ('من', 'كلامه'): 0.0009643201542912247,
#  ('كلامه', 'خليجي'): 0.3333333333333333,
#  ('خليجي', 'يسلملي'): 0.5,
#  ('يسلملي', 'مرورك'): 1.0,
#  ('مرورك', 'وروحك'): 0.3333333333333333,
#  ('وروحك', 'الحلوه'): 1.0,
#  ('الحلوه', 'وين'): 0.05555555555555555,
#  ('وين', 'هل'): 0.009259259259259259,
#  ('هل', 'الغيبه'): 0.03508771929824561,
#  ('الغيبه', 'اخ'): 0.5,
#  ('اخ', 'محمد'): 0.06666666666666667,
#  ('محمد', 'ياخي'): 0.041666666666666664,
#  ('ياخي', 'الارهابي'): 0.07142857142857142,
#  ('الارهابي', 'اذا'): 0.5,
#  ('اذا', 'كان'): 0.016877637130801686,
#  ('كان', 'عراقي'): 0.023809523809523808,
#  ('عراقي', 'سعودي'): 0.03125,
#  ('سعودي', 'فلسطيني'): 0.3333333333333333,
#  ('فلسطيني', 'وين'): 1.0,
#  ('وين', 'المشكله'): 0.046296296296296294,
#  ('المشكله', 'علي'): 0.02857142857142857,
#  ('علي', 'باب'): 0.006211180124223602,
#  ('باب', 'الفرضخليجي'): 0.05263157894736842,
#  ('الفرضخليجي', 'وماعنده'): 1.0,
#  ('وماعنده', 'رحمه'): 1.0,
#  ('رحمه', 'وين'): 0.08333333333333333,
#  ('وين', 'المساس'): 0.009259259259259259,
#  ('المساس', 'بقدسيتك'): 1.0,
#  ('بقدسيتك', 'اله'): 1.0,
#  ('اله', 'يرضي'): 0.008379888268156424,
#  ('يرضي', 'عنك'): 0.2857142857142857,
#  ('عنك', 'خلصت'): 0.1111111111111111,
#  ('خلصت', 'مشاكل'): 0.14285714285714285,
#  ('مشاكل', 'العرب'): 0.125,
#  ('العرب', 'واختلفنا'): 0.05,
#  ('واختلفنا', 'بجنسيت'): 1.0,
#  ('بجنسيت', 'ابو'): 1.0,
#  ('ابو', 'الطفل'): 0.010752688172043012,
#  ('الطفل', 'المغردين'): 0.2,
#  ('المغردين', 'سالوا'): 1.0,
#  ('سالوا', 'من'): 1.0,
#  ('من', 'وين'): 0.003857280617164899,
#  ('وين', 'ورجحت'): 0.009259259259259259,
#  ('ورجحت', 'وين'): 1.0,
#  ('وين', 'الكارثه'): 0.009259259259259259,
#  ('الكارثه', 'الي'): 0.5,
#  ('الي', 'وصلتك'): 0.0016778523489932886,
#  ('وصلتك', 'مطلبي'): 1.0,
#  ('مطلبي', 'يقدم'): 1.0,
#  ('يقدم', 'استقالته'): 0.25,
#  ('استقالته', 'وفوكاها'): 0.5,
#  ('وفوكاها', 'اعتذار'): 1.0,
#  ('اعتذار', 'خلص'): 1.0,
#  ('خلص', 'واله'): 0.06666666666666667,
#  ('واله', 'لعيونكم'): 0.002777777777777778,
#  ('لعيونكم', 'انا'): 1.0,
#  ('انا', 'ماعندي'): 0.008547008547008548,
#  ('ماعندي', 'شيء'): 0.07692307692307693,
#  ('شيء', 'معه'): 0.07692307692307693,
#  ('معه', 'بالعكس'): 0.125,
#  ('بالعكس', 'من'): 0.038461538461538464,
#  ('من', 'متابعيني'): 0.0009643201542912247,
#  ('متابعيني', 'الي'): 0.25,
#  ('الي', 'بعتز'): 0.0016778523489932886,
#  ('بعتز', 'فيهم'): 1.0,
#  ('فيهم', 'خلص'): 0.3333333333333333,
#  ('خلص', 'صافيه'): 0.06666666666666667,
#  ('صافيه', 'لبن'): 0.25,
#  ('لبن', 'يمكن'): 0.3333333333333333,
#  ('يمكن', 'سءال'): 0.030303030303030304,
#  ('سءال', 'فات'): 0.05555555555555555,
#  ('فات', 'الكثير'): 0.2,
#  ('الكثير', 'الي'): 0.5,
#  ('الي', 'يصور'): 0.0016778523489932886,
#  ('يصور', 'شنو'): 0.5,
#  ('شنو', 'موقفه'): 0.004405286343612335,
#  ('موقفه', 'وكانه'): 1.0,
#  ('وكانه', 'يوثق'): 1.0,
#  ('يوثق', 'بطوله'): 1.0,
#  ('بطوله', 'المفروض'): 0.25,
#  ('المفروض', 'حتي'): 0.05555555555555555,
#  ('حتي', 'المصور'): 0.005263157894736842,
#  ('المصور', 'يحال'): 1.0,
#  ('يحال', 'لقضاء'): 1.0,
#  ('لقضاء', 'لان'): 1.0,
#  ('لان', 'نظرات'): 0.0047169811320754715,
#  ('نظرات', 'الطفله'): 1.0,
#  ('الطفله', 'تستنجد'): 1.0,
#  ('تستنجد', 'باتجاه'): 1.0,
#  ('باتجاه', 'الكاميرا'): 1.0,
#  ('الكاميرا', 'اولا'): 0.3333333333333333,
#  ('اولا', 'اني'): 0.375,
#  ('اني', 'ردت'): 0.005319148936170213,
#  ('ردت', 'علي'): 0.1,
#  ('علي', 'رجل'): 0.004140786749482402,
#  ('رجل', 'جنوبي'): 0.07142857142857142,
#  ('جنوبي', 'والي'): 1.0,
#  ('والي', 'ذكر'): 0.025,
#  ('ذكر', 'حجابها'): 0.2,
#  ('حجابها', 'ثانيا'): 1.0,
#  ('ثانيا', 'انت'): 0.5,
#  ('انت', 'شدعوه'): 0.005154639175257732,
#  ('شدعوه', 'صايره'): 1.0,
#  ('صايره', 'محامي'): 0.030303030303030304,
#  ('محامي', 'لكوهين'): 0.3333333333333333,
#  ('لكوهين', 'صحيح'): 1.0,
#  ('صحيح', 'مقوله'): 0.023809523809523808,
#  ('مقوله', 'العراق'): 0.6666666666666666,
#  ('العراق', 'بلد'): 0.011111111111111112,
#  ('بلد', 'الغراءب'): 0.058823529411764705,
#  ('الغراءب', 'والعجاءب'): 1.0,
#  ('والعجاءب', 'واله'): 1.0,
#  ('واله', 'هذا'): 0.005555555555555556,
#  ('هذا', 'الموضوع'): 0.004048582995951417,
#  ('الموضوع', 'جدا'): 0.08333333333333333,
#  ('جدا', 'حساس'): 0.041666666666666664,
#  ('حساس', 'ويحير'): 0.2,
#  ('ويحير', 'اتفق'): 1.0,
#  ('اتفق', 'معك'): 0.3076923076923077,
#  ('معك', 'بس'): 0.2,
#  ('بس', 'انت'): 0.01694915254237288,
#  ('انت', 'لاتروح'): 0.005154639175257732,
#  ('لاتروح', 'زايد'): 1.0,
#  ('زايد', 'عادي'): 0.16666666666666666,
#  ('عادي', 'لا'): 0.023809523809523808,
#  ('لا', 'ان'): 0.006920415224913495,
#  ('ان', 'شاء'): 0.41414141414141414,
#  ('شاء', 'اله'): 0.9791666666666666,
#  ('اله', 'اخوه'): 0.002793296089385475,
#  ('اخوه', 'يجمعنه'): 0.1111111111111111,
#  ('يجمعنه', 'العراق'): 1.0,
#  ('العراق', 'الي'): 0.022222222222222223,
#  ('الي', 'بكل'): 0.0016778523489932886,
#  ('بكل', 'جحيمه'): 0.027777777777777776,
#  ('جحيمه', 'حلو'): 1.0,
#  ('حلو', 'يسعد'): 0.013157894736842105,
#  ('يسعد', 'مساك'): 0.4,
#  ('مساك', 'سيد'): 0.16666666666666666,
#  ('سيد', 'الحرف'): 0.1,
#  ('الحرف', 'الحزين'): 0.5,
#  ('الحزين', 'ه'): 0.5,
#  ('ه', 'عدوله'): 0.0033222591362126247,
#  ('عدوله', 'كلبه'): 0.5,
#  ('كلبه', 'ورم'): 0.6666666666666666,
#  ('ورم', 'من'): 1.0,
#  ('من', 'عدنه'): 0.0009643201542912247,
#  ('عدنه', 'كلك'): 0.043478260869565216,
#  ('كلك', 'خل'): 0.14285714285714285,
#  ('خل', 'اتونس'): 0.03333333333333333,
#  ('اتونس', 'همه'): 0.25,
#  ('همه', 'بكل'): 0.023809523809523808,
#  ('بكل', 'شيء'): 0.05555555555555555,
#  ('شيء', 'مارضين'): 0.07692307692307693,
#  ('مارضين', 'فهاي'): 1.0,
#  ('فهاي', 'السفره'): 1.0,
#  ('السفره', 'اسمها'): 1.0,
#  ('اسمها', 'اتونس'): 0.16666666666666666,
#  ('اتونس', 'وبكيفي'): 0.25,
#  ('وبكيفي', 'يسلملي'): 0.5,
#  ('مرورك', 'روعات'): 0.3333333333333333,
#  ('روعات', 'تواصلك'): 0.5,
#  ('تواصلك', 'يسعد'): 0.5,
#  ('مساك', 'بنت'): 0.16666666666666666,
#  ('بنت', 'العم'): 0.07142857142857142,
#  ('العم', 'ماخذ'): 0.25,
#  ('ماخذ', 'اي'): 0.2857142857142857,
#  ('اي', 'بشر'): 0.004081632653061225,
#  ('بشر', 'وحدي'): 0.1111111111111111,
#  ('وحدي', 'اتركه'): 0.125,
#  ('اتركه', 'فتره'): 0.5,
#  ('فتره', 'اذا'): 0.043478260869565216,
#  ('اذا', 'ماسال'): 0.004219409282700422,
#  ('ماسال', 'مايستحق'): 1.0,
#  ('مايستحق', 'اهتمامك'): 1.0,
#  ('اهتمامك', 'ياكلون'): 1.0,
#  ('ياكلون', 'بخيرنه'): 0.16666666666666666,
#  ('بخيرنه', 'ويهينون'): 1.0,
#  ('ويهينون', 'موظفينه'): 1.0,
#  ('موظفينه', 'عباله'): 1.0,
#  ('عباله', 'يرجع'): 0.14285714285714285,
#  ('يرجع', 'صدام'): 0.125,
#  ('صدام', 'حسين'): 0.027777777777777776,
#  ('حسين', 'لحكم'): 0.07692307692307693,
#  ('لحكم', 'ربي'): 1.0,
#  ('ربي', 'يعطيك'): 0.023255813953488372,
#  ('يعطيك', 'ويعطيهم'): 1.0,
#  ('ويعطيهم', 'الصحه'): 1.0,
#  ('الصحه', 'مع'): 0.2,
#  ('مع', 'قناعتي'): 0.011363636363636364,
#  ('قناعتي', 'انك'): 1.0,
#  ('انك', 'تنصح'): 0.07142857142857142,
#  ('تنصح', 'ولاتنصح'): 0.5,
#  ('ولاتنصح', 'اي'): 1.0,
#  ('اي', 'واله'): 0.15510204081632653,
#  ('واله', 'ملاحظه'): 0.002777777777777778,
#  ('ملاحظه', 'تستحق'): 0.25,
#  ('تستحق', 'الالتفات'): 0.5,
#  ('الالتفات', 'لها'): 1.0,
#  ('لها', 'لان'): 0.1111111111111111,
#  ('لان', 'الماضي'): 0.0047169811320754715,
#  ('الماضي', 'داءما'): 1.0,
#  ('داءما', 'فيه'): 0.058823529411764705,
#  ('فيه', 'ريحه'): 0.1111111111111111,
#  ('ريحه', 'خيانه'): 0.14285714285714285,
#  ('خيانه', 'ياله'): 0.5,
#  ('ياله', 'بدا'): 0.1,
#  ('بدا', 'الحراك'): 0.16666666666666666,
#  ('الحراك', 'والتطور'): 1.0,
#  ('والتطور', 'كل'): 1.0,
#  ('كل', 'جماعه'): 0.004464285714285714,
#  ('جماعه', 'علي'): 0.05263157894736842,
#  ('علي', 'قدر'): 0.004140786749482402,
#  ('قدر', 'عقولها'): 0.3333333333333333,
#  ('عقولها', 'المصيبه'): 1.0,
#  ('المصيبه', 'الشعب'): 0.5,
#  ('الشعب', 'يشوف'): 0.034482758620689655,
#  ('يشوف', 'ابن'): 0.04,
#  ('ابن', 'المرجع'): 0.02857142857142857,
#  ('المرجع', 'نبي'): 0.5,
#  ('نبي', 'وهذا'): 0.2,
#  ('وهذا', 'الي'): 0.15789473684210525,
#  ('الي', 'دمر'): 0.0016778523489932886,
#  ('دمر', 'العراق'): 0.4,
#  ('العراق', 'بالمنصور'): 0.011111111111111112,
#  ('بالمنصور', 'محمدنه'): 1.0,
#  ('محمدنه', 'ياخذ'): 1.0,
#  ('ياخذ', 'سلڤيات'): 0.1111111111111111,
#  ('سلڤيات', 'ابن'): 1.0,
#  ('ابن', 'عمي'): 0.08571428571428572,
#  ('عمي', 'حتي'): 0.047619047619047616,
#  ('حتي', 'الخوش'): 0.005263157894736842,
#  ('الخوش', 'بعد'): 1.0,
#  ('بعد', 'متكدر'): 0.007194244604316547,
#  ('متكدر', 'اتكول'): 0.5,
#  ('اتكول', 'عليه'): 0.3333333333333333,
#  ('عليه', 'خوش'): 0.010638297872340425,
#  ('خوش', 'من'): 0.0392156862745098,
#  ('من', 'وره'): 0.010607521697203472,
#  ('وره', 'الي'): 0.06666666666666667,
#  ('الي', 'نشوفه'): 0.0016778523489932886,
#  ('نشوفه', 'ونسمعه'): 0.3333333333333333,
#  ('ونسمعه', 'بس'): 1.0,
#  ('بس', 'ابو'): 0.004622496147919877,
#  ('ابو', 'جاسم'): 0.021505376344086023,
#  ('جاسم', 'يحب'): 0.3333333333333333,
#  ('يحب', 'الصور'): 0.058823529411764705,
#  ('الصور', 'منا'): 0.1111111111111111,
#  ('منا', 'ورايح'): 0.125,
#  ('ورايح', 'بعد'): 1.0,
#  ('بعد', 'ميغلط'): 0.007194244604316547,
#  ('ميغلط', 'بالحروف'): 1.0,
#  ('بالحروف', 'هذا'): 1.0,
#  ('هذا', 'درس'): 0.004048582995951417,
#  ('درس', 'لازم'): 1.0,
#  ('لازم', 'بالبصره'): 0.011904761904761904,
#  ('بالبصره', 'دزينه'): 0.125,
#  ('دزينه', 'شويه'): 1.0,
#  ('شويه', 'يسعد'): 0.03333333333333333,
#  ('مساك', 'استاذ'): 0.16666666666666666,
#  ('استاذ', 'نعمه'): 0.21052631578947367,
#  ('نعمه', 'يزيدني'): 0.1,
#  ('يزيدني', 'فخر'): 1.0,
#  ('فخر', 'تواصلك'): 0.16666666666666666,
#  ('تواصلك', 'تستاهلون'): 0.5,
#  ('تستاهلون', 'سويتوا'): 0.5,
#  ('سويتوا', 'ايران'): 0.3333333333333333,
#  ('ايران', 'مكه'): 0.018518518518518517,
#  ('مكه', 'اله'): 0.5,
#  ('اله', 'يشافيك'): 0.002793296089385475,
#  ('يشافيك', 'من'): 1.0,
#  ('من', 'مرض'): 0.0009643201542912247,
#  ('مرض', 'الدجل'): 0.16666666666666666,
#  ('الدجل', 'سبحان'): 1.0,
#  ('سبحان', 'اله'): 1.0,
#  ('اله', 'قبل'): 0.002793296089385475,
#  ('قبل', 'كم'): 0.04411764705882353,
#  ('كم', 'سنه'): 0.09523809523809523,
#  ('سنه', 'كنت'): 0.018867924528301886,
#  ('كنت', 'انت'): 0.05263157894736842,
#  ('انت', 'ومجموعه'): 0.005154639175257732,
#  ('ومجموعه', 'اطفال'): 1.0,
#  ('اطفال', 'هسه'): 0.1111111111111111,
#  ('هسه', 'صرت'): 0.010582010582010581,
#  ('صرت', 'تكلم'): 0.09090909090909091,
#  ('تكلم', 'عن'): 0.2222222222222222,
#  ('عن', 'المذهب'): 0.009900990099009901,
#  ('المذهب', 'الي'): 0.5,
#  ('الي', 'دمرتوه'): 0.003355704697986577,
#  ('دمرتوه', 'وخليتوا'): 0.5,
#  ('وخليتوا', 'العالم'): 1.0,
#  ('العالم', 'تضحك'): 0.03333333333333333,
#  ('تضحك', 'عليكم'): 0.1,
#  ('عليكم', 'كل'): 0.0625,
#  ('كل', 'شاذ'): 0.004464285714285714,
#  ('شاذ', 'بدا'): 1.0,
#  ('بدا', 'يتعذر'): 0.16666666666666666,
#  ('يتعذر', 'بالمذهب'): 1.0,
#  ('بالمذهب', 'طيب'): 1.0,
#  ('طيب', 'المرجعيه'): 0.05,
#  ('المرجعيه', 'وين'): 0.2,
#  ('وين', 'هءلاء'): 0.009259259259259259,
#  ('هءلاء', 'اخطر'): 0.5,
#  ('اخطر', 'من'): 0.5,
#  ('من', 'داعش'): 0.0009643201542912247,
#  ('داعش', 'وهسه'): 0.03333333333333333,
#  ('وهسه', 'مشاكل'): 0.058823529411764705,
#  ('مشاكل', 'العراق'): 0.125,
#  ('العراق', 'خلصت'): 0.011111111111111112,
#  ('خلصت', 'وبقت'): 0.14285714285714285,
#  ('وبقت', 'مشكله'): 1.0,
#  ('مشكله', 'البدون'): 0.05263157894736842,
#  ('البدون', 'مبروك'): 0.5,
#  ('مبروك', 'خالو'): 0.07142857142857142,
#  ('خالو', 'حضر'): 1.0,
#  ('حضر', 'عيديه'): 0.2,
#  ('عيديه', 'اجاك'): 0.3333333333333333,
#  ('اجاك', 'العيد'): 1.0,
#  ('العيد', 'منو'): 0.09090909090909091,
#  ('منو', 'يخاف'): 0.010101010101010102,
#  ('يخاف', 'منها'): 0.14285714285714285,
#  ('منها', 'علي'): 0.08333333333333333,
#  ('علي', 'كيفكم'): 0.002070393374741201,
#  ('كيفكم', 'تره'): 1.0,
#  ('تره', 'خبلتوها'): 0.030303030303030304,
#  ('خبلتوها', 'لحنان'): 1.0,
#  ('لحنان', 'بس'): 1.0,
#  ('بس', 'اتهمبل'): 0.0015408320493066256,
#  ('اتهمبل', 'واني'): 1.0,
#  ('واني', 'واني'): 0.025,
#  ('واني', 'شوفي'): 0.025,
#  ('شوفي', 'واضحه'): 0.05,
#  ('واضحه', 'ثقافتك'): 0.16666666666666666,
#  ('ثقافتك', 'بدايتها'): 0.5,
#  ('بدايتها', 'الصوره'): 0.3333333333333333,
#  ('الصوره', 'الي'): 0.14285714285714285,
#  ('الي', 'الظاهر'): 0.0016778523489932886,
#  ('الظاهر', 'انت'): 0.25,
#  ('انت', 'ملتزمه'): 0.005154639175257732,
#  ('ملتزمه', 'جدا'): 0.5,
#  ('جدا', 'حنان'): 0.041666666666666664,
#  ('حنان', 'الفتلاوي'): 0.5,
#  ('الفتلاوي', 'شخصيه'): 0.3333333333333333,
#  ('شخصيه', 'عامه'): 0.125,
#  ('عامه', 'من'): 0.3333333333333333,
#  ('من', 'حق'): 0.0028929604628736743,
#  ('حق', 'اي'): 0.18181818181818182,
#  ('اي', 'عراقي'): 0.004081632653061225,
#  ('عراقي', 'ينقدها'): 0.03125,
#  ('ينقدها', 'وياريت'): 1.0,
#  ('وياريت', 'لو'): 1.0,
#  ('لو', 'اتجوزن'): 0.0037593984962406013,
#  ('اتجوزن', 'من'): 1.0,
#  ('من', 'الواكه'): 0.0009643201542912247,
#  ('الواكه', 'منونه'): 1.0,
#  ('منونه', 'ويارب'): 0.1111111111111111,
#  ('ويارب', 'الامن'): 0.3333333333333333,
#  ('الامن', 'والامان'): 0.6666666666666666,
#  ('والامان', 'لمصر'): 0.25,
#  ('لمصر', 'الغاليه'): 1.0,
#  ('الغاليه', 'اي'): 0.14285714285714285,
#  ('واله', 'غريب'): 0.002777777777777778,
#  ('غريب', 'سكوتها'): 0.125,
#  ('سكوتها', 'منونه'): 1.0,
#  ('منونه', 'لجنابك'): 0.1111111111111111,
#  ('لجنابك', 'وكلامك'): 0.25,
#  ('وكلامك', 'الذهب'): 1.0,
#  ('الذهب', 'استاذ'): 0.25,
#  ('استاذ', 'محمد'): 0.10526315789473684,
#  ('محمد', 'لو'): 0.08333333333333333,
#  ('لو', 'اعرف'): 0.007518796992481203,
#  ('اعرف', 'الجماعه'): 0.013513513513513514,
#  ('الجماعه', 'شيحبون'): 0.05555555555555555,
#  ('شيحبون', 'لايريدون'): 1.0,
#  ('لايريدون', 'رياضه'): 1.0,
#  ('رياضه', 'ولافن'): 0.5,
#  ('ولافن', 'ولاثقافه'): 1.0,
#  ('ولاثقافه', 'ولاتعليم'): 1.0,
#  ('ولاتعليم', 'ولامطبقين'): 1.0,
#  ('ولامطبقين', 'الدين'): 1.0,
#  ('الدين', 'يعني'): 0.05,
#  ('يعني', 'بنوا'): 0.00390625,
#  ('بنوا', 'الملاعب'): 1.0,
#  ('الملاعب', 'لحوزه'): 1.0,
#  ('لحوزه', 'حيره'): 1.0,
#  ('حيره', 'هذه'): 0.3333333333333333,
#  ('هذه', 'مراسيم'): 0.023255813953488372,
#  ('مراسيم', 'شنو'): 1.0,
#  ('شنو', 'ومنو'): 0.004405286343612335,
#  ('ومنو', 'يتبعها'): 0.0625,
#  ('يتبعها', 'مكن'): 1.0,
#  ('مكن', 'توضيح'): 0.02040816326530612,
#  ('توضيح', 'الاخ'): 1.0,
#  ('الاخ', 'صاحب'): 0.09090909090909091,
#  ('صاحب', 'التغريده'): 0.42857142857142855,
#  ('التغريده', 'انا'): 0.05555555555555555,
#  ('انا', 'قلت'): 0.02564102564102564,
#  ('قلت', 'انا'): 0.1,
#  ('انا', 'وانت'): 0.017094017094017096,
#  ('وانت', 'والناس'): 0.02127659574468085,
#  ('والناس', 'السذج'): 0.16666666666666666,
#  ('السذج', 'ركز'): 0.5,
#  ('ركز', 'اخي'): 0.3333333333333333,
#  ('اخي', 'شبيه'): 0.058823529411764705,
#  ('شبيه', 'شريف'): 0.14285714285714285,
#  ('شريف', 'واخو'): 0.25,
#  ('واخو', 'اخيته'): 0.5,
#  ('اخيته', 'هاي'): 1.0,
#  ('هاي', 'بس'): 0.008130081300813009,
#  ('بس', 'يم'): 0.0015408320493066256,
#  ('يم', 'الكعبه'): 0.045454545454545456,
#  ('الكعبه', 'عرفتها'): 0.3333333333333333,
#  ('عرفتها', 'هنيالك'): 0.5,
#  ('هنيالك', 'ياعراقبعدين'): 1.0,
#  ('ياعراقبعدين', 'هذا'): 1.0,
#  ('هذا', 'حج'): 0.004048582995951417,
#  ('حج', 'لو'): 0.5,
#  ('لو', 'تصوير'): 0.0037593984962406013,
#  ('تصوير', 'افلام'): 0.3333333333333333,
#  ('افلام', 'كل'): 0.2,
#  ('كل', 'شوي'): 0.013392857142857142,
#  ('شوي', 'ناشرين'): 0.058823529411764705,
#  ('ناشرين', 'صورتك'): 1.0,
#  ('صورتك', 'كلامي'): 0.3333333333333333,
#  ('كلامي', 'غير'): 0.07692307692307693,
#  ('غير', 'موزون'): 0.013513513513513514,
#  ('موزون', 'اوزنوا'): 1.0,
#  ('اوزنوا', 'اقوالكم'): 1.0,
#  ('اقوالكم', 'وافعالكم'): 1.0,
#  ('وافعالكم', 'وغيروا'): 1.0,
#  ('وغيروا', 'مانتم'): 1.0,
#  ('مانتم', 'فيه'): 1.0,
#  ('فيه', 'ظلوا'): 0.1111111111111111,
#  ('ظلوا', 'بهاي'): 1.0,
#  ('بهاي', 'السوالف'): 0.25,
#  ('السوالف', 'من'): 0.16666666666666666,
#  ('من', 'بشر'): 0.0009643201542912247,
#  ('بشر', 'ينقد'): 0.1111111111111111,
#  ('ينقد', 'حاله'): 1.0,
#  ('حاله', 'تنسبوا'): 0.07692307692307693,
#  ('تنسبوا', 'لصدام'): 1.0,
#  ('لصدام', 'لان'): 0.5,
#  ('لان', 'انت'): 0.009433962264150943,
#  ('انت', 'كان'): 0.005154639175257732,
#  ('كان', 'يحكمك'): 0.023809523809523808,
#  ('يحكمك', 'نبي'): 1.0,
#  ('نبي', 'واحنه'): 0.2,
#  ('واحنه', 'صدام'): 0.06666666666666667,
#  ('صدام', 'بالعافيه'): 0.027777777777777776,
#  ('بالعافيه', 'عليك'): 0.42857142857142855,
#  ('عليك', 'وعلي'): 0.05,
#  ('وعلي', 'الرجال'): 0.0625,
#  ('الرجال', 'الي'): 0.1111111111111111,
#  ('الي', 'تحميك'): 0.0016778523489932886,
#  ('تحميك', 'الذله'): 1.0,
#  ('الذله', 'تليق'): 0.5,
#  ('تليق', 'بالبعض'): 1.0,
#  ('بالبعض', 'ويجيك'): 1.0,
#  ('ويجيك', 'بطران'): 0.3333333333333333,
#  ('بطران', 'يكول'): 0.5,
#  ('يكول', 'المرجعيه'): 0.018518518518518517,
#  ('المرجعيه', 'لاتدخل'): 0.2,
#  ('لاتدخل', 'بالسياسه'): 1.0,
#  ('بالسياسه', 'هذول'): 0.3333333333333333,
#  ('هذول', 'راح'): 0.2,
#  ('راح', 'نحر'): 0.006134969325153374,
#  ('نحر', 'بيهم'): 1.0,
#  ('بيهم', 'فلسطين'): 0.021739130434782608,
#  ('فلسطين', 'امين'): 0.16666666666666666,
#  ('امين', 'يارب'): 0.125,
#  ('يارب', 'ينعاد'): 0.023809523809523808,
#  ('ينعاد', 'عليك'): 0.2222222222222222,
#  ('عليك', 'بتحقيق'): 0.016666666666666666,
#  ('بتحقيق', 'كل'): 1.0,
#  ('كل', 'ماتمناه'): 0.004464285714285714,
#  ('ماتمناه', 'عيدك'): 1.0,
#  ('عيدك', 'مبارك'): 1.0,
#  ('مبارك', 'صحه'): 0.07142857142857142,
#  ('صحه', 'وسلامه'): 0.2857142857142857,
#  ('وسلامه', 'وانتم'): 0.2,
#  ('وانتم', 'بالف'): 0.3,
#  ('بالف', 'خير'): 0.8666666666666667,
#  ('خير', 'صحه'): 0.022727272727272728,
#  ('وسلامه', 'وراحه'): 0.2,
#  ('وراحه', 'البال'): 0.8333333333333334,
#  ('البال', 'عيدك'): 0.1111111111111111,
#  ('مبارك', 'وعساك'): 0.07142857142857142,
#  ('وعساك', 'من'): 1.0,
#  ('من', 'عواده'): 0.0048216007714561235,
#  ('عواده', 'وانت'): 0.2,
#  ('وانت', 'بخير'): 0.10638297872340426,
#  ('بخير', 'وسلامه'): 0.041666666666666664,
#  ('وسلامه', 'وربي'): 0.2,
#  ('وربي', 'ينعاد'): 0.1111111111111111,
#  ('ينعاد', 'عليكم'): 0.5555555555555556,
#  ('عليكم', 'بكل'): 0.03125,
#  ('بكل', 'ماتمنونه'): 0.027777777777777776,
#  ('ماتمنونه', 'وانت'): 0.5,
#  ('وانت', 'بالف'): 0.10638297872340426,
#  ('خير', 'ويارب'): 0.022727272727272728,
#  ('ويارب', 'تحقيق'): 0.3333333333333333,
#  ('تحقيق', 'كل'): 0.6666666666666666,
#  ('كل', 'ماتمنونه'): 0.004464285714285714,
#  ('ماتمنونه', 'وعساكم'): 0.5,
#  ('وعساكم', 'من'): 1.0,
#  ('عواده', 'من'): 0.2,
#  ('من', 'اخلاقك'): 0.0019286403085824494,
#  ('اخلاقك', 'الحلوه'): 0.6666666666666666,
#  ('الحلوه', 'كل'): 0.05555555555555555,
#  ('كل', 'عام'): 0.044642857142857144,
#  ('عام', 'وانتم'): 0.13636363636363635,
#  ('خير', 'اهلنه'): 0.022727272727272728,
#  ('اهلنه', 'وناسنه'): 1.0,
#  ('وناسنه', 'وفخرنه'): 1.0,
#  ('وفخرنه', 'كل'): 1.0,
#  ('وانتم', 'ترفلون'): 0.1,
#  ('ترفلون', 'بالعز'): 1.0,
#  ('بالعز', 'والسعاده'): 1.0,
#  ('والسعاده', 'وينعاد'): 0.16666666666666666,
#  ('وينعاد', 'عليكم'): 1.0,
#  ('عليكم', 'وسط'): 0.03125,
#  ('وسط', 'محبيكم'): 0.2,
#  ('محبيكم', 'واحبابكم'): 1.0,
#  ('واحبابكم', 'فديت'): 1.0,
#  ('فديت', 'العنونه'): 0.16666666666666666,
#  ('العنونه', 'العمر'): 1.0,
#  ('العمر', 'كله'): 0.23809523809523808,
#  ('كله', 'حبيبتي'): 0.017857142857142856,
#  ('حبيبتي', 'المعارض'): 0.07142857142857142,
#  ('المعارض', 'الحقيقي'): 1.0,
#  ('الحقيقي', 'الي'): 0.3333333333333333,
#  ('الي', 'بقي'): 0.0016778523489932886,
#  ('بقي', 'بسوريا'): 0.125,
#  ('بسوريا', 'والي'): 0.5,
#  ('والي', 'طلعوا'): 0.025,
#  ('طلعوا', 'كلهم'): 0.18181818181818182,
#  ('كلهم', 'خونه'): 0.037037037037037035,
#  ('خونه', 'باعوا'): 0.16666666666666666,
#  ('باعوا', 'بلدهم'): 0.5,
#  ('بلدهم', 'لمرتزقه'): 0.25,
#  ('لمرتزقه', 'ليس'): 1.0,
#  ('ليس', 'حبا'): 0.2,
#  ('حبا', 'بالاسد'): 0.3333333333333333,
#  ('بالاسد', 'لكن'): 1.0,
#  ('لكن', 'هاي'): 0.022222222222222223,
#  ('هاي', 'حقيقه'): 0.0040650406504065045,
#  ('حقيقه', 'مو'): 0.2,
#  ('مو', 'اتلومني'): 0.0017730496453900709,
#  ('اتلومني', 'من'): 1.0,
#  ('من', 'احچي'): 0.0009643201542912247,
#  ('احچي', 'شوف'): 0.3333333333333333,
#  ('شوف', 'دا'): 0.034482758620689655,
#  ('دا', 'يصير'): 0.038461538461538464,
#  ('يصير', 'بينه'): 0.013513513513513514,
#  ('بينه', 'واله'): 0.1111111111111111,
#  ('واله', 'اكو'): 0.005555555555555556,
#  ('اكو', 'قسم'): 0.008333333333333333,
#  ('قسم', 'سويت'): 0.14285714285714285,
#  ('سويت', 'احباط'): 0.09090909090909091,
#  ('احباط', 'عندي'): 1.0,
#  ('عندي', 'وين'): 0.011627906976744186,
#  ('وين', 'السمار'): 0.009259259259259259,
#  ('السمار', 'اله'): 1.0,
#  ('يرضي', 'عنكم'): 0.14285714285714285,
#  ('عنكم', 'سبحان'): 0.3333333333333333,
#  ('اله', 'احنه'): 0.00558659217877095,
#  ('احنه', 'العراقين'): 0.05102040816326531,
#  ('العراقين', 'يوميه'): 0.03125,
#  ('يوميه', 'طالعتنه'): 0.0625,
#  ('طالعتنه', 'مصيبه'): 1.0,
#  ('مصيبه', 'ملتهين'): 0.07142857142857142,
#  ('ملتهين', 'بيها'): 0.5,
#  ('بيها', 'هذا'): 0.011235955056179775,
#  ('هذا', 'يكول'): 0.004048582995951417,
#  ('يكول', 'السنه'): 0.018518518518518517,
#  ('السنه', 'وذاك'): 0.05,
#  ('وذاك', 'يكول'): 0.25,
#  ('يكول', 'الشيعه'): 0.018518518518518517,
#  ('الشيعه', 'وعلي'): 0.1111111111111111,
#  ('وعلي', 'هل'): 0.125,
#  ('هل', 'الرنه'): 0.03508771929824561,
#  ('الرنه', 'بس'): 0.5,
#  ('بس', 'العراقين'): 0.0015408320493066256,
#  ('العراقين', 'تحت'): 0.03125,
#  ('تحت', 'المجهر'): 0.14285714285714285,
#  ('المجهر', 'بخت'): 1.0,
#  ('بخت', 'ستار'): 0.25,
#  ('ستار', 'وبخت'): 1.0,
#  ('وبخت', 'ه'): 1.0,
#  ('ه', 'موج'): 0.0033222591362126247,
#  ('موج', 'البحر'): 1.0,
#  ('البحر', 'عوفي'): 0.5,
#  ('عوفي', 'الحمص'): 1.0,
#  ('الحمص', 'سولفينه'): 1.0,
#  ('سولفينه', 'عليه'): 1.0,
#  ('عليه', 'علي'): 0.010638297872340425,
#  ('علي', 'هذا'): 0.016563146997929608,
#  ('هذا', 'انت'): 0.004048582995951417,
#  ('انت', 'اتخوف'): 0.005154639175257732,
#  ('اتخوف', 'كرايب'): 0.3333333333333333,
#  ('كرايب', 'الجماعه'): 1.0,
#  ('الجماعه', 'بكيفك'): 0.05555555555555555,
#  ('بكيفك', 'بطولات'): 0.5,
#  ('بطولات', 'انجازات'): 1.0,
#  ('انجازات', 'قرارات'): 0.5,
#  ('قرارات', 'ه'): 1.0,
#  ('ه', 'ايفانكا'): 0.0033222591362126247,
#  ('ايفانكا', 'تبين'): 1.0,
#  ('تبين', 'كاسره'): 0.14285714285714285,
#  ('كاسره', 'خاطرك'): 1.0,
#  ('خاطرك', 'استاذ'): 0.5,
#  ('محمد', 'منونه'): 0.041666666666666664,
#  ('منونه', 'لخاطري'): 0.1111111111111111,
#  ('لخاطري', 'امسحه'): 0.5,
#  ('امسحه', 'وعلق'): 1.0,
#  ('وعلق', 'خوالك'): 1.0,
#  ('خوالك', 'يموتون'): 1.0,
#  ('يموتون', 'علي'): 0.3333333333333333,
#  ('علي', 'النكد'): 0.002070393374741201,
#  ('النكد', 'لهذا'): 1.0,
#  ('لهذا', 'في'): 0.125,
#  ('في', 'شجن'): 0.009259259259259259,
#  ('شجن', 'بكل'): 1.0,
#  ('بكل', 'مايقولونه'): 0.027777777777777776,
#  ('مايقولونه', 'اني'): 1.0,
#  ('اني', 'هم'): 0.05319148936170213,
#  ('هم', 'راح'): 0.02702702702702703,
#  ('راح', 'احضره'): 0.006134969325153374,
#  ('احضره', 'زين'): 1.0,
#  ('زين', 'نبهتني'): 0.016129032258064516,
#  ('نبهتني', 'لحد'): 1.0,
#  ('لحد', 'الان'): 0.3870967741935484,
#  ('الان', 'ماعرف'): 0.027777777777777776,
#  ('ماعرف', 'دافع'): 0.037037037037037035,
#  ('دافع', 'جوابه'): 0.3333333333333333,
#  ('جوابه', 'ردي'): 1.0,
#  ('ردي', 'كان'): 0.5,
#  ('كان', 'طبيعي'): 0.023809523809523808,
#  ('طبيعي', 'مافيه'): 0.1,
#  ('مافيه', 'ازعاج'): 1.0,
#  ('ازعاج', 'مبدع'): 1.0,
#  ('مبدع', 'ومحد'): 0.3333333333333333,
#  ('ومحد', 'داري'): 0.125,
#  ('داري', 'بيك'): 0.5,
#  ('بيك', 'لا'): 0.03571428571428571,
#  ('لا', 'ابد'): 0.006920415224913495,
#  ('ابد', 'مامنزله'): 0.037037037037037035,
#  ('مامنزله', 'ايدي'): 1.0,
#  ('ايدي', 'ولاشكلي'): 0.08333333333333333,
#  ('ولاشكلي', 'لاتسوينه'): 1.0,
#  ('لاتسوينه', 'مشكله'): 1.0,
#  ('مشكله', 'اله'): 0.05263157894736842,
#  ('عنك', 'اقتراحاتك'): 0.1111111111111111,
#  ('اقتراحاتك', 'رهيبه'): 1.0,
#  ('رهيبه', 'كلك'): 0.2,
#  ('كلك', 'افكار'): 0.14285714285714285,
#  ('افكار', 'حج'): 1.0,
#  ('حج', 'مبرور'): 0.5,
#  ('مبرور', 'وسعي'): 1.0,
#  ('وسعي', 'مشكور'): 1.0,
#  ('مشكور', 'وهو'): 0.25,
#  ('وهو', 'شخسران'): 0.02631578947368421,
#  ('شخسران', 'نوري'): 1.0,
#  ('نوري', 'المالكي'): 0.42857142857142855,
#  ('المالكي', 'ولد'): 0.07142857142857142,
#  ('ولد', 'الخايبات'): 0.038461538461538464,
#  ('الخايبات', 'الي'): 1.0,
#  ('الي', 'بقوا'): 0.0016778523489932886,
#  ('بقوا', 'يخليهم'): 1.0,
#  ('يخليهم', 'حطب'): 0.3333333333333333,
#  ('حطب', 'لفزعاته'): 0.5,
#  ('لفزعاته', 'خاف'): 1.0,
#  ('خاف', 'اكو'): 0.1,
#  ('اكو', 'بلد'): 0.008333333333333333,
#  ('بلد', 'لسه'): 0.058823529411764705,
#  ('لسه', 'اسمه'): 0.16666666666666666,
#  ('اسمه', 'العراق'): 0.04,
#  ('العراق', 'التسرع'): 0.011111111111111112,
#  ('التسرع', 'بالحكم'): 1.0,
#  ('بالحكم', 'او'): 1.0,
#  ('او', 'اتخاذ'): 0.006756756756756757,
#  ('اتخاذ', 'القرار'): 1.0,
#  ('القرار', 'ولو'): 0.3333333333333333,
#  ('ولو', 'علي'): 0.047619047619047616,
#  ('علي', 'ماضن'): 0.002070393374741201,
#  ('ماضن', 'متحتاج'): 1.0,
#  ('متحتاج', 'نصيحه'): 0.5,
#  ('نصيحه', 'هذا'): 0.25,
#  ('هذا', 'مريض'): 0.004048582995951417,
#  ('مريض', 'عنده'): 0.2,
#  ('عنده', 'حاله'): 0.01639344262295082,
#  ('حاله', 'نفسيه'): 0.3076923076923077,
#  ('نفسيه', 'صعبه'): 0.1,
#  ('صعبه', 'ان'): 0.08333333333333333,
#  ('ان', 'يرجع'): 0.010101010101010102,
#  ('يرجع', 'حرا'): 0.125,
#  ('حرا', 'كل'): 1.0,
#  ('كل', 'هذا'): 0.017857142857142856,
#  ('هذا', 'ومامقصوده'): 0.004048582995951417,
#  ('ومامقصوده', 'اذا'): 1.0,
#  ('اذا', 'مقصوده'): 0.004219409282700422,
#  ('مقصوده', 'شلون'): 0.125,
#  ('شلون', 'صح'): 0.009174311926605505,
#  ('صح', 'لسانك'): 0.045454545454545456,
#  ('لسانك', 'الجهل'): 0.14285714285714285,
#  ('الجهل', 'افه'): 0.5,
#  ('افه', 'ياله'): 1.0,
#  ('ياله', 'عليه'): 0.1,
#  ('عليه', 'تكاليف'): 0.010638297872340425,
#  ('تكاليف', 'حفله'): 1.0,
#  ('حفله', 'حنتك'): 0.2,
#  ('حنتك', 'ماعرف'): 1.0,
#  ('ماعرف', 'هاي'): 0.037037037037037035,
#  ('هاي', 'حكومه'): 0.0040650406504065045,
#  ('حكومه', 'لو'): 0.08333333333333333,
#  ('لو', 'علوه'): 0.0037593984962406013,
#  ('علوه', 'مخضر'): 1.0,
#  ('مخضر', 'ه'): 1.0,
#  ('ه', 'واله'): 0.03986710963455149,
#  ('واله', 'اني'): 0.019444444444444445,
#  ('هم', 'شاكه'): 0.006756756756756757,
#  ('شاكه', 'احنه'): 1.0,
#  ('احنه', 'المقصودين'): 0.01020408163265306,
#  ('المقصودين', 'لان'): 1.0,
#  ('لان', 'الدلاءل'): 0.0047169811320754715,
#  ('الدلاءل', 'كلها'): 1.0,
#  ('كلها', 'لاتشير'): 0.027777777777777776,
#  ('لاتشير', 'علينا'): 1.0,
#  ('علينا', 'منونه'): 0.043478260869565216,
#  ('منونه', 'سيد'): 0.1111111111111111,
#  ('سيد', 'يسعد'): 0.1,
#  ('يسعد', 'صباحك'): 0.2,
#  ('صباحك', 'اسمعت'): 0.16666666666666666,
#  ('اسمعت', 'لو'): 1.0,
#  ('لو', 'ناديت'): 0.0037593984962406013,
#  ('ناديت', 'حيا'): 1.0,
#  ('حيا', 'وربك'): 1.0,
#  ('وربك', 'متاخذغير'): 0.125,
#  ('متاخذغير', 'القهر'): 1.0,
#  ('القهر', 'والتعب'): 0.5,
#  ('والتعب', 'والضيم'): 0.5,
#  ('والضيم', 'والمرض'): 1.0,
#  ('والمرض', 'ويخلص'): 0.5,
#  ('ويخلص', 'عمرها'): 0.5,
#  ('عمرها', 'حتي'): 0.5,
#  ('حتي', 'يرضي'): 0.005263157894736842,
#  ('يرضي', 'وتربي'): 0.14285714285714285,
#  ('وتربي', 'اولاده'): 1.0,
#  ('اولاده', 'هاي'): 0.5,
#  ('بس', 'المراءه'): 0.0015408320493066256,
#  ('المراءه', 'العربيه'): 1.0,
#  ('العربيه', 'شلونك'): 0.1111111111111111,
#  ('شلونك', 'شلون'): 0.07142857142857142,
#  ('شلون', 'صحتك'): 0.009174311926605505,
#  ('صحتك', 'عافيتك'): 0.5,
#  ('عافيتك', 'شلون'): 0.5,
#  ('شلون', 'الاهل'): 0.009174311926605505,
#  ('الاهل', 'ان'): 0.25,
#  ('اله', 'زنين'): 0.002793296089385475,
#  ('زنين', 'يستاهل'): 1.0,
#  ('يستاهل', 'بس'): 0.1,
#  ('بس', 'اعتقد'): 0.004622496147919877,
#  ('اعتقد', 'مو'): 0.05,
#  ('مو', 'زوجها'): 0.0017730496453900709,
#  ('زوجها', 'ولا'): 0.25,
#  ('ولا', 'جوال'): 0.006993006993006993,
#  ('جوال', 'تبين'): 1.0,
#  ('تبين', 'شغلته'): 0.14285714285714285,
#  ('شغلته', 'چبيره'): 0.3333333333333333,
#  ('چبيره', 'ه'): 0.5,
#  ('ه', 'هاي'): 0.013289036544850499,
#  ('هاي', 'النسوان'): 0.008130081300813009,
#  ('النسوان', 'الي'): 0.125,
#  ('الي', 'تعمر'): 0.0016778523489932886,
#  ('تعمر', 'بيوت'): 1.0,
#  ('بيوت', 'يعني'): 0.25,
#  ('يعني', 'المشاكل'): 0.00390625,
#  ('المشاكل', 'جابت'): 0.16666666666666666,
#  ('جابت', 'نتيجه'): 0.16666666666666666,
#  ('نتيجه', 'كلام'): 0.25,
#  ('كلام', 'منطقي'): 0.03333333333333333,
#  ('منطقي', 'جدا'): 0.3333333333333333,
#  ('جدا', 'اتفق'): 0.041666666666666664,
#  ('معك', 'هلو'): 0.1,
#  ('هلو', 'رغوده'): 0.1,
#  ('رغوده', 'شنو'): 1.0,
#  ('شنو', 'هل'): 0.04405286343612335,
#  ('الغيبه', 'ان'): 0.5,
#  ('اله', 'خير'): 0.00558659217877095,
#  ('خير', 'منوره'): 0.022727272727272728,
#  ('منوره', 'روعات'): 0.3333333333333333,
#  ('روعات', 'مرورك'): 0.5,
#  ('مرورك', 'استاذي'): 0.3333333333333333,
#  ('استاذي', 'الفاضل'): 0.3333333333333333,
#  ('الفاضل', 'حلوه'): 1.0,
#  ('حلوه', 'بالعراق'): 0.023255813953488372,
#  ('بالعراق', 'انجمد'): 0.017241379310344827,
#  ('انجمد', 'البانيه'): 1.0,
#  ('البانيه', 'لشتاء'): 1.0,
#  ('لشتاء', 'والباكله'): 1.0,
#  ('والباكله', 'لصيف'): 1.0,
#  ('لصيف', 'احنه'): 0.3333333333333333,
#  ('احنه', 'هم'): 0.02040816326530612,
#  ('هم', 'مطورين'): 0.006756756756756757,
#  ('مطورين', 'سنه'): 1.0,
#  ('سنه', 'يسولف'): 0.018867924528301886,
#  ('يسولف', 'برفع'): 0.3333333333333333,
#  ('برفع', 'الصبات'): 1.0,
#  ('الصبات', 'والي'): 0.5,
#  ('والي', 'اعتبره'): 0.025,
#  ('اعتبره', 'الوكيه'): 0.2,
#  ('الوكيه', 'منجز'): 1.0,
#  ('منجز', 'وسنه'): 1.0,
#  ('وسنه', 'يرفع'): 0.5,
#  ('يرفع', 'التجاوز'): 0.3333333333333333,
#  ('التجاوز', 'ات'): 0.5,
#  ('ات', 'والحكم'): 1.0,
#  ('والحكم', 'لجنابك'): 1.0,
#  ('لجنابك', 'لنشاط'): 0.25,
#  ('لنشاط', 'رءيس'): 1.0,
#  ('رءيس', 'الوزراء'): 0.2727272727272727,
#  ('الوزراء', 'العالم'): 0.2,
#  ('العالم', 'والمدن'): 0.03333333333333333,
#  ('والمدن', 'اصبحت'): 1.0,
#  ('اصبحت', 'تباري'): 0.25,
#  ('تباري', 'في'): 1.0,
#  ('في', 'الهندسه'): 0.009259259259259259,
#  ('الهندسه', 'والجمال'): 1.0,
#  ('والجمال', 'والرفاهيه'): 0.5,
#  ('والرفاهيه', 'وهذا'): 1.0,
#  ('وهذا', 'فرحان'): 0.05263157894736842,
#  ('فرحان', 'رفع'): 0.5,
#  ('رفع', 'صبه'): 0.25,
#  ('صبه', 'الطم'): 1.0,
#  ('الطم', 'هذا'): 0.5,
#  ('هذا', 'كله'): 0.004048582995951417,
#  ('كله', 'حتي'): 0.017857142857142856,
#  ('حتي', 'يبقي'): 0.010526315789473684,
#  ('يبقي', 'اقتصاد'): 0.06666666666666667,
#  ('اقتصاد', 'ايران'): 1.0,
#  ('ايران', 'متوازن'): 0.018518518518518517,
#  ('متوازن', 'والعراق'): 0.5,
#  ('والعراق', 'الي'): 0.16666666666666666,
#  ('الي', 'جهنم'): 0.0016778523489932886,
#  ('جهنم', 'لو'): 0.2,
#  ('لو', 'بس'): 0.0037593984962406013,
#  ('بس', 'افتهم'): 0.0015408320493066256,
#  ('افتهم', 'هذوله'): 0.2,
#  ('هذوله', 'عدهم'): 0.125,
#  ('عدهم', 'شرف'): 0.05,
#  ('شرف', 'الانتماء'): 0.5,
#  ('الانتماء', 'لبلدهم'): 1.0,
#  ('لبلدهم', 'ابو'): 1.0,
#  ('ابو', 'العدس'): 0.021505376344086023,
#  ('العدس', 'وينه'): 0.2,
#  ('وينه', 'كبسوله'): 0.1,
#  ('كبسوله', 'كل'): 1.0,
#  ('كل', 'ست'): 0.004464285714285714,
#  ('ست', 'ساعات'): 0.25,
#  ('ساعات', 'صدقتي'): 0.1,
#  ('صدقتي', 'عزيزتي'): 1.0,
#  ('عزيزتي', 'يسعد'): 0.16666666666666666,
#  ('مساك', 'يعني'): 0.16666666666666666,
#  ('يعني', 'انسوي'): 0.00390625,
#  ('انسوي', 'ثوره'): 1.0,
#  ('ثوره', 'تقبلون'): 0.2,
#  ('تقبلون', 'اخاف'): 0.3333333333333333,
#  ('اخاف', 'نقود'): 0.06666666666666667,
#  ('نقود', 'ثوره'): 1.0,
#  ('ثوره', 'وبنهايه'): 0.2,
#  ('وبنهايه', 'ايصير'): 1.0,
#  ('ايصير', 'بيها'): 0.5,
#  ('بيها', 'اشكال'): 0.011235955056179775,
#  ('اشكال', 'شرعي'): 0.2,
#  ('شرعي', 'تكلم'): 1.0,
#  ('تكلم', 'بثقه'): 0.1111111111111111,
#  ('بثقه', 'وكانك'): 0.5,
#  ('وكانك', 'رءيس'): 1.0,
#  ('الوزراء', 'شكد'): 0.2,
#  ('شكد', 'عمرك'): 0.022727272727272728,
#  ('عمرك', 'بروح'): 0.07692307692307693,
#  ('بروح', 'ابوك'): 1.0,
#  ('ابوك', 'في'): 0.1111111111111111,
#  ('في', 'وقفتكم'): 0.009259259259259259,
#  ('وقفتكم', 'هندسه'): 1.0,
#  ('هندسه', 'بالتوفيق'): 0.3333333333333333,
#  ('بالتوفيق', 'لجميع'): 0.5,
#  ('لجميع', 'ان'): 0.2,
#  ('اله', 'قمر'): 0.002793296089385475,
#  ('قمر', 'سوريا'): 0.25,
#  ('سوريا', 'يكون'): 0.3333333333333333,
#  ('يكون', 'احلي'): 0.030303030303030304,
#  ('احلي', 'بيكم'): 0.02631578947368421,
#  ('بيكم', 'استقالته'): 0.047619047619047616,
#  ('استقالته', 'ليس'): 0.5,
#  ('ليس', 'بالظروره'): 0.2,
#  ('بالظروره', 'انه'): 1.0,
#  ('انه', 'ضعيف'): 0.029411764705882353,
#  ('ضعيف', 'مكن'): 0.2,
#  ('مكن', 'عاجزان'): 0.02040816326530612,
#  ('عاجزان', 'يبقي'): 1.0,
#  ('يبقي', 'نزيه'): 0.06666666666666667,
#  ('نزيه', 'فضل'): 0.5,
#  ('فضل', 'الانسحاب'): 0.3333333333333333,
#  ('الانسحاب', 'واله'): 1.0,
#  ('واله', 'اعلم'): 0.002777777777777778,
#  ('اعلم', 'اله'): 0.5,
#  ('اله', 'لايوفقچ'): 0.002793296089385475,
#  ('لايوفقچ', 'علي'): 1.0,
#  ('هذا', 'الفرض'): 0.004048582995951417,
#  ('الفرض', 'شيسوي'): 1.0,
#  ('شيسوي', 'بالجان'): 0.2,
#  ('بالجان', 'هذا'): 1.0,
#  ('هذا', 'انسان'): 0.004048582995951417,
#  ('انسان', 'عايش'): 0.06666666666666667,
#  ('عايش', 'بغير'): 0.08333333333333333,
#  ('بغير', 'عالم'): 0.125,
#  ('عالم', 'بس'): 0.25,
#  ('بس', 'حلو'): 0.0015408320493066256,
#  ('حلو', 'يمثل'): 0.013157894736842105,
#  ('يمثل', 'الحبوب'): 0.5,
#  ('الحبوب', 'الطيب'): 1.0,
#  ('الطيب', 'لايك'): 0.16666666666666666,
#  ('لايك', 'عليه'): 0.125,
#  ('عليه', 'الدور'): 0.010638297872340425,
#  ('الدور', 'منونه'): 0.5,
#  ('منونه', 'انت'): 0.1111111111111111,
#  ('انت', 'تمون'): 0.005154639175257732,
#  ('تمون', 'اخ'): 1.0,
#  ('اخ', 'راقي'): 0.06666666666666667,
#  ('راقي', 'واله'): 0.2,
#  ('واله', 'يطلع'): 0.002777777777777778,
#  ('يطلع', 'الواحد'): 0.029411764705882353,
#  ('الواحد', 'من'): 0.2,
#  ('من', 'دينه'): 0.0009643201542912247,
#  ('دينه', 'هذا'): 1.0,
#  ('هذا', 'مصيبه'): 0.004048582995951417,
#  ('مصيبه', 'اله'): 0.07142857142857142,
#  ('اله', 'بلانه'): 0.00558659217877095,
#  ('بلانه', 'بيه'): 0.5,
#  ('بيه', 'ه'): 0.00909090909090909,
#  ('ه', 'ماشي'): 0.0033222591362126247,
#  ('ماشي', 'اتركها'): 0.3333333333333333,
#  ('اتركها', 'لك'): 0.5,
#  ('لك', 'كل'): 0.05714285714285714,
#  ('كل', 'ماتحب'): 0.004464285714285714,
#  ('ماتحب', 'احترم'): 1.0,
#  ('احترم', 'بكل'): 0.3333333333333333,
#  ('بكل', 'قهر'): 0.027777777777777776,
#  ('قهر', 'قناعتك'): 0.2,
#  ('قناعتك', 'ايڤون'): 1.0,
#  ('ايڤون', 'بلاص'): 1.0,
#  ('بلاص', 'اخذته'): 1.0,
#  ('اخذته', 'قبل'): 0.2,
#  ('قبل', 'سنوات'): 0.014705882352941176,
#  ('سنوات', 'مليون'): 0.16666666666666666,
#  ('مليون', 'وشويه'): 0.1,
#  ('وشويه', 'نفسه'): 0.3333333333333333,
#  ('نفسه', 'واله'): 0.041666666666666664,
#  ('واله', 'استاذ'): 0.002777777777777778,
#  ('نعمه', 'مو'): 0.1,
#  ('مو', 'من'): 0.01773049645390071,
#  ('من', 'هواه'): 0.0009643201542912247,
#  ('هواه', 'التغير'): 1.0,
#  ('التغير', 'بسرعه'): 0.14285714285714285,
#  ('بسرعه', 'واشوفه'): 0.1111111111111111,
#  ('واشوفه', 'بعده'): 0.5,
#  ('بعده', 'جديد'): 0.125,
#  ('جديد', 'كدامك'): 0.09090909090909091,
#  ('كدامك', 'استاذي'): 0.3333333333333333,
#  ('استاذي', 'ماكان'): 0.3333333333333333,
#  ('ماكان', 'عندي'): 1.0,
#  ('عندي', 'خبر'): 0.023255813953488372,
#  ('خبر', 'شكرا'): 0.1111111111111111,
#  ('شكرا', 'لمعلومه'): 0.02702702702702703,
#  ('لمعلومه', 'اعتقد'): 1.0,
#  ('اعتقد', 'اولادها'): 0.05,
#  ('اولادها', 'من'): 1.0,
#  ('من', 'الزوج'): 0.0009643201542912247,
#  ('الزوج', 'الثاني'): 0.5,
#  ('الثاني', 'يحق'): 0.125,
#  ...}
